# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://techproeducation.com/logo/headerlogo.svg" class="img-fluid" alt="TECHPRO"></p>
#
# ___

# %% [markdown]
# # Proje Adı: Film İncelemesi
#
# ## Projenin amacı:
#
# Bu proje ile mini bir EDA (Exploratory Data Analysis) ve farklı veri görselleştirme kütüphanaleri kullanarak film verilerini incelemek ve farklı filmler arasındaki ilişkileri keşfet amaçlanmıştır.
#
# ## Veri Seti:
#
# Araştırmada 2006-2016 yılları arasındaki yapılmış filmlerin yer aldığı "IMDB-Movie-Data"  veri seti kullanılacaktır. Veri seti kısaca yıllara göre IMDB'de en yüksek puan alan filmleri içermektedir. Data setinde her film için aşağıdaki değişkenler yer almaktadır:
#
#     Rank
#     Title
#     Genre
#     Description
#     Director
#     Actors
#     Year
#     Runtime (Minutes)
#     Rating
#     Votes
#     Revenue (Millions)
#     Metascore
#
# Bu kapsamda aşağıdaki görevleri yapmanız gerekmektedir.
#
# ## Görevler :
#
# ### 1. Veri setini pandas kütüphanesi kullanarak yükleyin ve index sütununu filmin başlığı yapın.
#
# ### 2. Veri setini tanıyın.
#
# ### 3. Veri setindeki sütun isimlerini kullanışlı hale getirin (Örn: Kısaltıp küçük harf yapmak gibi)
#
# ### 4. Missing Value tespit edilsin ve bu kapsamda aşağıdaki şekilde mücadele edilsin.
#     a.Missing value kontrolü hem pandas hemde missingno kütüphanelerini kullanarak yapın
#     b.Yüksek missing value olan değişken içindeki veriler o değişkenin ortalama skoru ile
#     doldurulsun.
#     c. Düşük missing value olan değişkendeki gözlemler kaldırılsın.
#     d. Missing value kontrolü tekrar hem pandas hemde missingno kütüphanelerini kullanarak kontrol edin ve bu data setini yeni bir değişkene atayın.
#
# ### 5. Temizlenmiş veri seti içinden en yüksek rating e sahip 250 filmi seçerek "top250" isminde bir data seti oluşturun ve bunu lokalinize bu isimle kaydedin. Bu yeni data setini tekrar pandas kütüphanesini kullanarak okuyun.
#
# ### 6. Veri setinin boyutunu ve özelliklerini inceleyin.
#     a. Veri setinin boyutunu inceleme
#     b. Veri setinin ilk 5 gözlemine göz atma
#     c. Random olarak 10 gözleme bakma
#     d. Veri setinin sütunlarına göz atma
#     e. Veri setinin özet istatistiklerini görüntüleme
#
# ### 7. Verilerin doğruluğunun ve eksik değerlerinin olup olmadığını kontrol edin.
#     a. 4.madde ile benzer şelkilde eksik değerlerinin olup olmadığını kontrol
#
# ### 8. Verileri görselleştirme:
#
#     a. Matplotlib kütüphanesi kullanarak, yıllara göre filmlerin sayısını gösteren bir çizgi grafik çizin.
#     b. Seaborn kütüphanesi kullanarak, en çok film yapılan 10 türü bar grafiğiyle gösterin.
#     c. Matplotlib kütüphanesi kullanarak, film türlerine göre filmlerin sayısını gösteren pasta grafik çizin.
#
#
# ### 9. İlişkileri görselleştirme:
#
#     a. Seaborn kütüphanesi kullanarak, veri setindeki nümerik değişkenlerin korelasyonunu
#     gösteren bir heatmap çizin.
#     b. Seaborn ile oyunculardan birden fazla filmde rol alan oyuncuların rol aldıkları film
#     sayılarına göre ilk 20 oyucuyu görselleştir. Not: Bu soru için kullanılacak data setimiz 936
#     satırlık data seti olacak.
#     c. Popüler 250 Filmin rating puanlarına göre hasılatını herhangi bir grafik ile gösterin .
#
#
#
# ### 10. Sonuçları sunma:
#
#     Çizilen tüm görsellerle ilgili elde ettiğiniz bulguları buraya yazınız.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Veri setini pandas kütüphanesi kullanarak yükleyin ve index sütununu filmin başlığı yapın

# %%
imdb = pd.read_csv("IMDB-Movie-Data.csv")
imdb
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 995  A tight-knit team of rising investigators, alo...             Billy Ray
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...        Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# 2                  117     7.3  157606              138.12       62.0
# 3                  108     7.2   60545              270.32       59.0
# 4                  123     6.2  393727              325.02       40.0
# ..                 ...     ...     ...                 ...        ...
# 995                111     6.2   27585                 NaN       45.0
# 996                 94     5.5   73152               17.54       46.0
# 997                 98     6.2   70699               58.01       50.0
# 998                 93     5.6    4881                 NaN       22.0
# 999                 87     5.3   12435               19.64       11.0
#
# [1000 rows x 12 columns]

# %%
imdb.set_index("Title", drop=False)
imdb.sample(8)
# Out:
#      Rank                    Title                       Genre  \
# 463   464           Predestination        Drama,Mystery,Sci-Fi
# 170   171             Nightcrawler        Crime,Drama,Thriller
# 543   544          P.S. I Love You               Drama,Romance
# 667   668                    Ted 2    Adventure,Comedy,Romance
# 213   214                  Old Boy        Action,Drama,Mystery
# 819   820       Wolves at the Door             Horror,Thriller
# 904   905                  RoboCop         Action,Crime,Sci-Fi
# 558   559  In the Heart of the Sea  Action,Adventure,Biography
#
#                                            Description             Director  \
# 463  For his final assignment, a top temporal agent...      Michael Spierig
# 170  When Louis Bloom, a con man desperate for work...           Dan Gilroy
# 543  A young widow discovers that her late husband ...  Richard LaGravenese
# 667  Newlywed couple Ted and Tami-Lynn want to have...      Seth MacFarlane
# 213  Obsessed with vengeance, a man sets out to fin...            Spike Lee
# 819  Four friends gather at an elegant home during ...     John R. Leonetti
# 904  In 2028 Detroit, when Alex Murphy - a loving h...         José Padilha
# 558  A recounting of a New England whaling ship's s...           Ron Howard
#
#                                                 Actors  Year  \
# 463  Ethan Hawke, Sarah Snook, Noah Taylor, Madelei...  2014
# 170  Jake Gyllenhaal, Rene Russo, Bill Paxton, Riz ...  2014
# 543  Hilary Swank, Gerard Butler, Harry Connick Jr....  2007
# 667  Mark Wahlberg, Seth MacFarlane, Amanda Seyfrie...  2015
# 213  Josh Brolin, Elizabeth Olsen, Samuel L. Jackso...  2013
# 819  Katie Cassidy, Elizabeth Henstridge, Adam Camp...  2016
# 904  Joel Kinnaman, Gary Oldman, Michael Keaton, Ab...  2014
# 558  Chris Hemsworth, Cillian Murphy, Brendan Glees...  2015
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 463                 97     7.5  187760                 NaN       69.0
# 170                118     7.9  332476               32.28       76.0
# 543                126     7.1  177247               53.68        NaN
# 667                115     6.3  136323               81.26       48.0
# 213                104     5.8   54679                 NaN       49.0
# 819                 73     4.6     564                 NaN       63.0
# 904                117     6.2  190833               58.61       52.0
# 558                122     6.9   90372               24.99       47.0

# %% [markdown]
# ## 2. Veri setini tanıyın

# %%
imdb.sample(10)
# Out:
#      Rank                                  Title                       Genre  \
# 286   287            Keeping Up with the Joneses               Action,Comedy
# 645   646                            Gran Torino                       Drama
# 595   596                              Let Me In        Drama,Horror,Mystery
# 891   892                             This Is 40              Comedy,Romance
# 268   269               X-Men Origins: Wolverine     Action,Adventure,Sci-Fi
# 759   760                            The Fighter      Action,Biography,Drama
# 255   256                           The Hangover                      Comedy
# 422   423        Pride and Prejudice and Zombies       Action,Horror,Romance
# 408   409  The Hunger Games: Mockingjay - Part 2     Action,Adventure,Sci-Fi
# 23     24                                 Trolls  Animation,Adventure,Comedy
#
#                                            Description          Director  \
# 286  A suburban couple becomes embroiled in an inte...      Greg Mottola
# 645  Disgruntled Korean War veteran Walt Kowalski s...    Clint Eastwood
# 595  A bullied young boy befriends a young female v...       Matt Reeves
# 891  Pete and Debbie are both about to turn 40, the...       Judd Apatow
# 268  A look at Wolverine's early life, in particula...        Gavin Hood
# 759  A look at the early years of boxer "Irish" Mic...  David O. Russell
# 255  Three buddies wake up from a bachelor party in...     Todd Phillips
# 422  Five sisters in 19th century England must cope...       Burr Steers
# 408  As the war of Panem escalates to the destructi...  Francis Lawrence
# 23   After the Bergens invade Troll Village, Poppy,...        Walt Dohrn
#
#                                                 Actors  Year  \
# 286  Zach Galifianakis, Isla Fisher, Jon Hamm, Gal ...  2016
# 645  Clint Eastwood, Bee Vang, Christopher Carley,A...  2008
# 595  Kodi Smit-McPhee, Chloë Grace Moretz, Richard ...  2010
# 891  Paul Rudd, Leslie Mann, Maude Apatow, Iris Apatow  2012
# 268  Hugh Jackman, Liev Schreiber, Ryan Reynolds, D...  2009
# 759  Mark Wahlberg, Christian Bale, Amy Adams,Melis...  2010
# 255  Zach Galifianakis, Bradley Cooper, Justin Bart...  2009
# 422  Lily James, Sam Riley, Jack Huston, Bella Heat...  2016
# 408  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...  2015
# 23   Anna Kendrick, Justin Timberlake,Zooey Deschan...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 286                105     5.8   30405               14.90       34.0
# 645                116     8.2  595779              148.09        NaN
# 595                116     7.2   97141               12.13       79.0
# 891                134     6.2  108156               67.52        NaN
# 268                107     6.7  388447              179.88       40.0
# 759                116     7.8  290056               93.57       79.0
# 255                100     7.8  611563              277.31       73.0
# 422                108     5.8   35003               10.91       45.0
# 408                137     6.6  202380              281.67       65.0
# 23                  92     6.5   38552              153.69       56.0

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
imdb.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# 2                False   False  False               False      False
# 3                False   False  False               False      False
# 4                False   False  False               False      False
# ..                 ...     ...    ...                 ...        ...
# 995              False   False  False                True      False
# 996              False   False  False               False      False
# 997              False   False  False               False      False
# 998              False   False  False                True      False
# 999              False   False  False               False      False
#
# [1000 rows x 12 columns]

# %%
imdb.describe().T
# Out:
#                      count           mean            std     min       25%  \
# Rank                1000.0     500.500000     288.819436     1.0    250.75
# Year                1000.0    2012.783000       3.205962  2006.0   2010.00
# Runtime (Minutes)   1000.0     113.172000      18.810908    66.0    100.00
# Rating              1000.0       6.723200       0.945429     1.9      6.20
# Votes               1000.0  169808.255000  188762.647518    61.0  36309.00
# Revenue (Millions)   872.0      82.956376     103.253540     0.0     13.27
# Metascore            936.0      58.985043      17.194757    11.0     47.00
#
#                            50%         75%         max
# Rank                   500.500     750.250     1000.00
# Year                  2014.000    2016.000     2016.00
# Runtime (Minutes)      111.000     123.000      191.00
# Rating                   6.800       7.400        9.00
# Votes               110799.000  239909.750  1791916.00
# Revenue (Millions)      47.985     113.715      936.63
# Metascore               59.500      72.000      100.00

# %%
imdb.describe(include="all").T
# Out:
#                      count unique  \
# Rank                1000.0    NaN
# Title                 1000    999
# Genre                 1000    207
# Description           1000   1000
# Director              1000    644
# Actors                1000    996
# Year                1000.0    NaN
# Runtime (Minutes)   1000.0    NaN
# Rating              1000.0    NaN
# Votes               1000.0    NaN
# Revenue (Millions)   872.0    NaN
# Metascore            936.0    NaN
#
#                                                                   top freq  \
# Rank                                                              NaN  NaN
# Title                                                        The Host    2
# Genre                                         Action,Adventure,Sci-Fi   50
# Description         A group of intergalactic criminals are forced ...    1
# Director                                                 Ridley Scott    8
# Actors              Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...    2
# Year                                                              NaN  NaN
# Runtime (Minutes)                                                 NaN  NaN
# Rating                                                            NaN  NaN
# Votes                                                             NaN  NaN
# Revenue (Millions)                                                NaN  NaN
# Metascore                                                         NaN  NaN
#
#                           mean            std     min      25%       50%  \
# Rank                     500.5     288.819436     1.0   250.75     500.5
# Title                      NaN            NaN     NaN      NaN       NaN
# Genre                      NaN            NaN     NaN      NaN       NaN
# Description                NaN            NaN     NaN      NaN       NaN
# Director                   NaN            NaN     NaN      NaN       NaN
# Actors                     NaN            NaN     NaN      NaN       NaN
# Year                  2012.783       3.205962  2006.0   2010.0    2014.0
# Runtime (Minutes)      113.172      18.810908    66.0    100.0     111.0
# Rating                  6.7232       0.945429     1.9      6.2       6.8
# Votes               169808.255  188762.647518    61.0  36309.0  110799.0
# Revenue (Millions)   82.956376      103.25354     0.0    13.27    47.985
# Metascore            58.985043      17.194757    11.0     47.0      59.5
#
#                           75%        max
# Rank                   750.25     1000.0
# Title                     NaN        NaN
# Genre                     NaN        NaN
# Description               NaN        NaN
# Director                  NaN        NaN
# Actors                    NaN        NaN
# Year                   2016.0     2016.0
# Runtime (Minutes)       123.0      191.0
# Rating                    7.4        9.0
# Votes               239909.75  1791916.0
# Revenue (Millions)    113.715     936.63
# Metascore                72.0      100.0

# %% [markdown]
# ## 3. Veri setindeki sütun isimlerini kullanışlı hale getirin

# %%
imdb.rename(columns={'Runtime (Minutes)': 'Runtime_min',
                     'Revenue (Millions)' : 'Revenue_mil'}, 
            inplace=True)
imdb.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime_min  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012          124
#
#    Rating   Votes  Revenue_mil  Metascore
# 0     8.1  757074       333.13       76.0
# 1     7.0  485820       126.46       65.0

# %% [markdown]
# ## 4. Missing Value tespit edilsin ve bu kapsamda aşağıdaki şekilde mücadele edilsin.

# %% [markdown]
# #### a.Missing value kontrolü hem pandas hemde missingno kütüphanelerini kullanarak yapın

# %%
miss_val_count = imdb.isnull().sum()
miss_val_count
# Out:
# Rank             0
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime_min      0
# Rating           0
# Votes            0
# Revenue_mil    128
# Metascore       64
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(imdb);

# %% [markdown]
# #### b.Yüksek missing value olan değişken içindeki veriler o değişkenin ortalama skoru ile doldurulsun.

# %%
revenue_median = imdb["Revenue_mil"].median()
revenue_median
# Out:
# 47.985

# %%
imdb["Revenue_mil"].fillna(revenue_median, inplace=True)
msno.matrix(imdb);

# %%
imdb["Metascore"].fillna(imdb["Metascore"].median(), inplace = True)
msno.matrix(imdb);

# %% [markdown]
# #### c. Düşük missing value olan değişkendeki gözlemler kaldırılsın.

# %%
imdb.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### d. Missing value kontrolü tekrar hem pandas hemde missingno kütüphanelerini kullanarak kontrol edin ve bu data setini yeni bir değişkene atayın.

# %%
msno.matrix(imdb);

# %%
msno.bar(imdb);

# %% [markdown]
# ## 5. Temizlenmiş veri seti içinden en yüksek rating e sahip 250 filmi seçerek "top250" isminde bir data seti oluşturun ve bunu lokalinize bu isimle kaydedin. Ardından bu yeni data setini tekrar pandas kütüphanesini kullanarak okuyun.

# %%
top = imdb.sort_values(by = "Rating", ascending=False)
top250 = top[:250]
top250
# Out:
#      Rank                                           Title  \
# 54     55                                 The Dark Knight
# 80     81                                       Inception
# 117   118                                          Dangal
# 36     37                                    Interstellar
# 96     97                                   Kimi no na wa
# ..    ...                                             ...
# 327   328                          A Street Cat Named Bob
# 650   651  Sweeney Todd: The Demon Barber of Fleet Street
# 146   147                           The Edge of Seventeen
# 708   709                                       The Judge
# 313   314       The Hobbit: The Battle of the Five Armies
#
#                        Genre  \
# 54        Action,Crime,Drama
# 80   Action,Adventure,Sci-Fi
# 117   Action,Biography,Drama
# 36    Adventure,Drama,Sci-Fi
# 96   Animation,Drama,Fantasy
# ..                       ...
# 327   Biography,Comedy,Drama
# 650     Drama,Horror,Musical
# 146             Comedy,Drama
# 708              Crime,Drama
# 313        Adventure,Fantasy
#
#                                            Description            Director  \
# 54   When the menace known as the Joker wreaks havo...   Christopher Nolan
# 80   A thief, who steals corporate secrets through ...   Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...       Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...   Christopher Nolan
# 96   Two strangers find themselves linked in a biza...      Makoto Shinkai
# ..                                                 ...                 ...
# 327  Based on the international best selling book. ...  Roger Spottiswoode
# 650  The infamous story of Benjamin Barker, a.k.a. ...          Tim Burton
# 146  High-school life gets even more unbearable for...  Kelly Fremon Craig
# 708  Big-city lawyer Hank Palmer returns to his chi...        David Dobkin
# 313  Bilbo and Company are forced to engage in a wa...       Peter Jackson
#
#                                                 Actors  Year  Runtime_min  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008          152
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010          148
# 117  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016          161
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014          169
# 96   Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016          106
# ..                                                 ...   ...          ...
# 327  Luke Treadaway, Bob the Cat, Ruta Gedmintas, J...  2016          103
# 650  Johnny Depp, Helena Bonham Carter, Alan Rickma...  2007          116
# 146  Hailee Steinfeld, Haley Lu Richardson, Blake J...  2016          104
# 708  Robert Downey Jr., Robert Duvall, Vera Farmiga...  2014          141
# 313  Ian McKellen, Martin Freeman, Richard Armitage...  2014          144
#
#      Rating    Votes  Revenue_mil  Metascore
# 54      9.0  1791916       533.32       82.0
# 80      8.8  1583625       292.57       74.0
# 117     8.8    48969        11.15       59.5
# 36      8.6  1047747       187.99       74.0
# 96      8.6    34110         4.68       79.0
# ..      ...      ...          ...        ...
# 327     7.4    12643         0.04       54.0
# 650     7.4   296289        52.88       83.0
# 146     7.4    47694        14.26       77.0
# 708     7.4   146812        47.11       48.0
# 313     7.4   385598       255.11       59.0
#
# [250 rows x 12 columns]

# %%
top250.to_csv("Top250")

# %% [markdown]
# ## 6. Veri setinin boyutunu ve özelliklerini inceleyin

# %% [markdown]
# #### a. Veri setinin boyutunu inceleme

# %%
top_250 = pd.read_csv("Top250")
top_250
# Out:
#      Unnamed: 0  Rank                                           Title  \
# 0            54    55                                 The Dark Knight
# 1            80    81                                       Inception
# 2           117   118                                          Dangal
# 3            36    37                                    Interstellar
# 4            96    97                                   Kimi no na wa
# ..          ...   ...                                             ...
# 245         327   328                          A Street Cat Named Bob
# 246         650   651  Sweeney Todd: The Demon Barber of Fleet Street
# 247         146   147                           The Edge of Seventeen
# 248         708   709                                       The Judge
# 249         313   314       The Hobbit: The Battle of the Five Armies
#
#                        Genre  \
# 0         Action,Crime,Drama
# 1    Action,Adventure,Sci-Fi
# 2     Action,Biography,Drama
# 3     Adventure,Drama,Sci-Fi
# 4    Animation,Drama,Fantasy
# ..                       ...
# 245   Biography,Comedy,Drama
# 246     Drama,Horror,Musical
# 247             Comedy,Drama
# 248              Crime,Drama
# 249        Adventure,Fantasy
#
#                                            Description            Director  \
# 0    When the menace known as the Joker wreaks havo...   Christopher Nolan
# 1    A thief, who steals corporate secrets through ...   Christopher Nolan
# 2    Former wrestler Mahavir Singh Phogat and his t...       Nitesh Tiwari
# 3    A team of explorers travel through a wormhole ...   Christopher Nolan
# 4    Two strangers find themselves linked in a biza...      Makoto Shinkai
# ..                                                 ...                 ...
# 245  Based on the international best selling book. ...  Roger Spottiswoode
# 246  The infamous story of Benjamin Barker, a.k.a. ...          Tim Burton
# 247  High-school life gets even more unbearable for...  Kelly Fremon Craig
# 248  Big-city lawyer Hank Palmer returns to his chi...        David Dobkin
# 249  Bilbo and Company are forced to engage in a wa...       Peter Jackson
#
#                                                 Actors  Year  Runtime_min  \
# 0    Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008          152
# 1    Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010          148
# 2    Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016          161
# 3    Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014          169
# 4    Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016          106
# ..                                                 ...   ...          ...
# 245  Luke Treadaway, Bob the Cat, Ruta Gedmintas, J...  2016          103
# 246  Johnny Depp, Helena Bonham Carter, Alan Rickma...  2007          116
# 247  Hailee Steinfeld, Haley Lu Richardson, Blake J...  2016          104
# 248  Robert Downey Jr., Robert Duvall, Vera Farmiga...  2014          141
# 249  Ian McKellen, Martin Freeman, Richard Armitage...  2014          144
#
#      Rating    Votes  Revenue_mil  Metascore
# 0       9.0  1791916       533.32       82.0
# 1       8.8  1583625       292.57       74.0
# 2       8.8    48969        11.15       59.5
# 3       8.6  1047747       187.99       74.0
# 4       8.6    34110         4.68       79.0
# ..      ...      ...          ...        ...
# 245     7.4    12643         0.04       54.0
# 246     7.4   296289        52.88       83.0
# 247     7.4    47694        14.26       77.0
# 248     7.4   146812        47.11       48.0
# 249     7.4   385598       255.11       59.0
#
# [250 rows x 13 columns]

# %%
top_250.size
# Out:
# 3250

# %%
top_250.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   250 non-null    int64
#  1   Rank         250 non-null    int64
#  2   Title        250 non-null    object
#  3   Genre        250 non-null    object
#  4   Description  250 non-null    object
#  5   Director     250 non-null    object
#  6   Actors       250 non-null    object
#  7   Year         250 non-null    int64
#  8   Runtime_min  250 non-null    int64
#  9   Rating       250 non-null    float64
#  10  Votes        250 non-null    int64
#  11  Revenue_mil  250 non-null    float64
#  12  Metascore    250 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 25.5+ KB

# %% [markdown]
# #### b. Veri setinin ilk 5 gözlemine göz atma

# %%
top_250.head()
# Out:
#    Unnamed: 0  Rank            Title                    Genre  \
# 0          54    55  The Dark Knight       Action,Crime,Drama
# 1          80    81        Inception  Action,Adventure,Sci-Fi
# 2         117   118           Dangal   Action,Biography,Drama
# 3          36    37     Interstellar   Adventure,Drama,Sci-Fi
# 4          96    97    Kimi no na wa  Animation,Drama,Fantasy
#
#                                          Description           Director  \
# 0  When the menace known as the Joker wreaks havo...  Christopher Nolan
# 1  A thief, who steals corporate secrets through ...  Christopher Nolan
# 2  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 3  A team of explorers travel through a wormhole ...  Christopher Nolan
# 4  Two strangers find themselves linked in a biza...     Makoto Shinkai
#
#                                               Actors  Year  Runtime_min  \
# 0  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008          152
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010          148
# 2  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016          161
# 3  Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014          169
# 4  Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016          106
#
#    Rating    Votes  Revenue_mil  Metascore
# 0     9.0  1791916       533.32       82.0
# 1     8.8  1583625       292.57       74.0
# 2     8.8    48969        11.15       59.5
# 3     8.6  1047747       187.99       74.0
# 4     8.6    34110         4.68       79.0

# %% [markdown]
# #### c. Random olarak 10 gözleme bakma

# %%
top_250.sample(10)
# Out:
#      Unnamed: 0  Rank                             Title  \
# 71          140   141                         Star Trek
# 216         643   644                            Frantz
# 50          197   198                     Into the Wild
# 220         918   919  Perfume: The Story of a Murderer
# 230         475   476                   Eddie the Eagle
# 207         681   682       We Need to Talk About Kevin
# 65          273   274                       Sing Street
# 182         460   461                          The Town
# 179          37    38                    Doctor Strange
# 231         851   852                       Begin Again
#
#                          Genre  \
# 71     Action,Adventure,Sci-Fi
# 216          Drama,History,War
# 50   Adventure,Biography,Drama
# 220        Crime,Drama,Fantasy
# 230     Biography,Comedy,Drama
# 207     Drama,Mystery,Thriller
# 65          Comedy,Drama,Music
# 182       Crime,Drama,Thriller
# 179   Action,Adventure,Fantasy
# 231                Drama,Music
#
#                                            Description          Director  \
# 71   The brash James T. Kirk tries to live up to hi...       J.J. Abrams
# 216  In the aftermath of WWI, a young German who gr...     François Ozon
# 50   After graduating from Emory University, top st...         Sean Penn
# 220  Jean-Baptiste Grenouille, born with a superior...        Tom Tykwer
# 230  The story of Eddie Edwards, the notoriously te...   Dexter Fletcher
# 207  Kevin's mother struggles to love her strange c...      Lynne Ramsay
# 65   A boy growing up in Dublin during the 1980s es...       John Carney
# 182  As he plans his next job, a longtime thief tri...       Ben Affleck
# 179  While on a journey of physical and spiritual h...  Scott Derrickson
# 231  A chance encounter between a disgraced music-b...       John Carney
#
#                                                 Actors  Year  Runtime_min  \
# 71   Chris Pine, Zachary Quinto, Simon Pegg, Leonar...  2009          127
# 216  Pierre Niney, Paula Beer, Ernst Stötzner, Mari...  2016          113
# 50   Emile Hirsch, Vince Vaughn, Catherine Keener, ...  2007          148
# 220  Ben Whishaw, Dustin Hoffman, Alan Rickman,Fran...  2006          147
# 230  Taron Egerton, Hugh Jackman, Tom Costello, Jo ...  2016          106
# 207  Tilda Swinton, John C. Reilly, Ezra Miller, Ja...  2011          112
# 65   Ferdia Walsh-Peelo, Aidan Gillen, Maria Doyle ...  2016          106
# 182  Ben Affleck, Rebecca Hall, Jon Hamm, Jeremy Re...  2010          125
# 179  Benedict Cumberbatch, Chiwetel Ejiofor, Rachel...  2016          115
# 231  Keira Knightley, Mark Ruffalo, Adam Levine, Ha...  2013          104
#
#      Rating   Votes  Revenue_mil  Metascore
# 71      8.0  526324       257.70       82.0
# 216     7.5    4304         0.86       73.0
# 50      8.1  459304        18.35       73.0
# 220     7.5  199387         2.21       56.0
# 230     7.4   56332        15.79       54.0
# 207     7.5  104953         1.74       68.0
# 65      8.0   52144         3.23       79.0
# 182     7.6  294553        92.17       74.0
# 179     7.6  293732       232.60       72.0
# 231     7.4  111875        16.17       62.0

# %% [markdown]
# #### d. Veri setinin sütunlarına göz atma

# %%
top_250.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Title', 'Genre', 'Description', 'Director',
#        'Actors', 'Year', 'Runtime_min', 'Rating', 'Votes', 'Revenue_mil',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# #### e. Veri setinin özet istatistiklerini görüntüleme

# %%
top_250.describe().T
# Out:
#              count          mean            std      min          25%  \
# Unnamed: 0   250.0     391.17200     280.038678     0.00     145.2500
# Rank         250.0     392.17200     280.038678     1.00     146.2500
# Year         250.0    2011.93600       3.384928  2006.00    2009.0000
# Runtime_min  250.0     123.39200      22.191896    66.00     106.0000
# Rating       250.0       7.82800       0.309968     7.40       7.6000
# Votes        250.0  320995.75600  264185.276251    61.00  120036.5000
# Revenue_mil  250.0     114.43092     137.455458     0.01      18.5125
# Metascore    250.0      72.99800      12.287184    34.00      65.2500
#
#                     50%          75%         max
# Unnamed: 0      333.000     639.0000      991.00
# Rank            334.000     640.0000      992.00
# Year           2013.000    2015.0000     2016.00
# Runtime_min     120.000     137.7500      191.00
# Rating            7.800       8.0000        9.00
# Votes        290307.500  455535.2500  1791916.00
# Revenue_mil      55.465     165.9575      936.63
# Metascore        74.000      81.0000      100.00

# %% [markdown]
# ## 7. Verilerin doğruluğunun ve eksik değerlerinin olup olmadığını kontrol edin.¶
#
# Not: 4.madde ile benzer şelkilde kontrol edebilirsiniz.

# %%
top_250.isnull()
# Out:
#      Unnamed: 0   Rank  Title  Genre  Description  Director  Actors   Year  \
# 0         False  False  False  False        False     False   False  False
# 1         False  False  False  False        False     False   False  False
# 2         False  False  False  False        False     False   False  False
# 3         False  False  False  False        False     False   False  False
# 4         False  False  False  False        False     False   False  False
# ..          ...    ...    ...    ...          ...       ...     ...    ...
# 245       False  False  False  False        False     False   False  False
# 246       False  False  False  False        False     False   False  False
# 247       False  False  False  False        False     False   False  False
# 248       False  False  False  False        False     False   False  False
# 249       False  False  False  False        False     False   False  False
#
#      Runtime_min  Rating  Votes  Revenue_mil  Metascore
# 0          False   False  False        False      False
# 1          False   False  False        False      False
# 2          False   False  False        False      False
# 3          False   False  False        False      False
# 4          False   False  False        False      False
# ..           ...     ...    ...          ...        ...
# 245        False   False  False        False      False
# 246        False   False  False        False      False
# 247        False   False  False        False      False
# 248        False   False  False        False      False
# 249        False   False  False        False      False
#
# [250 rows x 13 columns]

# %%
top_250.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 8. Verileri görselleştirme:

# %% [markdown]
# #### a. Matplotlib kütüphanesi kullanarak, yıllara göre filmlerin sayısını gösteren bir çizgi grafik çizin.

# %%
count_movie = top_250["Year"].value_counts().sort_index()
count_movie
# Out:
# 2006    17
# 2007    21
# 2008    14
# 2009    21
# 2010    18
# 2011    17
# 2012    16
# 2013    21
# 2014    30
# 2015    18
# 2016    57
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.plot(count_movie.index, count_movie.values, lw = 4, color = "m")

plt.show()

# %% [markdown]
# #### b. Seaborn kütüphanesi kullanarak, en çok film yapılan 10 türü bar grafiğiyle gösterin.

# %%
genre_split = imdb['Genre'].str.split(',', expand=True).stack()
genre_counts = genre_split.value_counts()
top_10_genre = genre_counts.head(10)
print(top_10_genre)
# Out:
# Drama        513
# Action       303
# Comedy       279
# Adventure    259
# Thriller     195
# Crime        150
# Romance      141
# Sci-Fi       120
# Horror       119
# Mystery      106
# dtype: int64

# %%
sns.barplot(x=top_10_genre.index, y=top_10_genre.values, palette='viridis')
plt.xticks(rotation = 75);

# %% [markdown]
# #### c. Matplotlib kütüphanesi kullanarak, film türlerine göre filmlerin sayısını gösteren pasta grafik çizin.

# %%
ten_genre_labels = ten_genre.index

plt.figure(figsize=(8, 8))
plt.pie(ten_genre, labels = ten_genre_labels, autopct='%1.2f%%');

# %% [markdown]
# ## 9. İlişkileri görselleştirme

# %% [markdown]
# #### a. Seaborn kütüphanesi kullanarak, veri setindeki nümerik değişkenlerin korelasyonunu gösteren bir heatmap çizin.

# %%
top_250.drop("Unnamed: 0", axis = 1, inplace = True)
top_250.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime_min', 'Rating', 'Votes', 'Revenue_mil', 'Metascore'],
#       dtype='object')

# %%
corr_top_250 = top_250.corr()
sns.heatmap(corr_top_250, annot=True);

# %% [markdown]
# #### b. Seaborn ile oyunculardan birden fazla filmde rol alan oyuncuların rol aldıkları film sayılarına göre ilk 20 oyucuyu görselleştir.
#
# #### Not: Bu soru için kullanılacak data setimiz 936 satırlık data seti olacak.

# %%
genre_split = imdb['Genre'].str.split(',', expand=True).stack()
genre_counts = genre_split.value_counts()
top_10_genre = genre_counts.head(10)
print(top_10_genre)

# %%
actors_split = imdb["Actors"].str.split(",", expand=True).stack()
actors_count = actors_split.value_counts()
to_20_actors = actors_count.head(20)
to_20_actors
# Out:
# Christian Bale         11
# Mark Wahlberg          11
#  Woody Harrelson        9
# Jake Gyllenhaal         9
# Matthew McConaughey     9
# Brad Pitt               9
# Adam Sandler            9
# Will Smith              9
# Leonardo DiCaprio       9
#  Rose Byrne             9
# Denzel Washington       9
# Johnny Depp             8
# Tom Hanks               8
# Robert Downey Jr.       8
#  Chloë Grace Moretz     8
#  Morgan Freeman         8
# Daniel Radcliffe        8
# Tom Hardy               8
#  Scarlett Johansson     8
#  Cate Blanchett         8
# dtype: int64

# %%
sns.barplot(x=to_20_actors.index, y=to_20_actors.values, palette='flare')
plt.xticks(rotation = 75);

# %% [markdown]
# #### c. Popüler 250 Filmin rating puanlarına göre hasılatını herhangi bir grafik ile gösterin .

# %%
top_250
# Out:
#      Rank                                           Title  \
# 0      55                                 The Dark Knight
# 1      81                                       Inception
# 2     118                                          Dangal
# 3      37                                    Interstellar
# 4      97                                   Kimi no na wa
# ..    ...                                             ...
# 245   328                          A Street Cat Named Bob
# 246   651  Sweeney Todd: The Demon Barber of Fleet Street
# 247   147                           The Edge of Seventeen
# 248   709                                       The Judge
# 249   314       The Hobbit: The Battle of the Five Armies
#
#                        Genre  \
# 0         Action,Crime,Drama
# 1    Action,Adventure,Sci-Fi
# 2     Action,Biography,Drama
# 3     Adventure,Drama,Sci-Fi
# 4    Animation,Drama,Fantasy
# ..                       ...
# 245   Biography,Comedy,Drama
# 246     Drama,Horror,Musical
# 247             Comedy,Drama
# 248              Crime,Drama
# 249        Adventure,Fantasy
#
#                                            Description            Director  \
# 0    When the menace known as the Joker wreaks havo...   Christopher Nolan
# 1    A thief, who steals corporate secrets through ...   Christopher Nolan
# 2    Former wrestler Mahavir Singh Phogat and his t...       Nitesh Tiwari
# 3    A team of explorers travel through a wormhole ...   Christopher Nolan
# 4    Two strangers find themselves linked in a biza...      Makoto Shinkai
# ..                                                 ...                 ...
# 245  Based on the international best selling book. ...  Roger Spottiswoode
# 246  The infamous story of Benjamin Barker, a.k.a. ...          Tim Burton
# 247  High-school life gets even more unbearable for...  Kelly Fremon Craig
# 248  Big-city lawyer Hank Palmer returns to his chi...        David Dobkin
# 249  Bilbo and Company are forced to engage in a wa...       Peter Jackson
#
#                                                 Actors  Year  Runtime_min  \
# 0    Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008          152
# 1    Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010          148
# 2    Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016          161
# 3    Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014          169
# 4    Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016          106
# ..                                                 ...   ...          ...
# 245  Luke Treadaway, Bob the Cat, Ruta Gedmintas, J...  2016          103
# 246  Johnny Depp, Helena Bonham Carter, Alan Rickma...  2007          116
# 247  Hailee Steinfeld, Haley Lu Richardson, Blake J...  2016          104
# 248  Robert Downey Jr., Robert Duvall, Vera Farmiga...  2014          141
# 249  Ian McKellen, Martin Freeman, Richard Armitage...  2014          144
#
#      Rating    Votes  Revenue_mil  Metascore
# 0       9.0  1791916       533.32       82.0
# 1       8.8  1583625       292.57       74.0
# 2       8.8    48969        11.15       59.5
# 3       8.6  1047747       187.99       74.0
# 4       8.6    34110         4.68       79.0
# ..      ...      ...          ...        ...
# 245     7.4    12643         0.04       54.0
# 246     7.4   296289        52.88       83.0
# 247     7.4    47694        14.26       77.0
# 248     7.4   146812        47.11       48.0
# 249     7.4   385598       255.11       59.0
#
# [250 rows x 12 columns]

# %%
sns.pairplot(top_250, hue = "Year");

# %% [markdown]
# ## 10. Conclusion (Sonuçları sunma)

# %% [markdown]
# # T E B R İ K L E R

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://techproeducation.com/logo/headerlogo.svg" class="img-fluid" alt="TECHPRO"></p>
#
# ___
