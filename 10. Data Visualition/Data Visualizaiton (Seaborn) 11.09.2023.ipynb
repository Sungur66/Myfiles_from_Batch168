# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib notebook

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Scatter Plot

# %%
# %matplotlib notebook
sns.scatterplot(x = "total_bill", y = "tip", data = tips);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.figure(figsize = (9,5))
sns.regplot(data = tips, x = "total_bill", y = "tip");  
# gölge güven araligi ni belirtiyor. gölge genisliyorsa güven azaliyor. 
# regresyon = bagimsiz degiskenin, bagimli degiskenle aciklama, aciklamaya calsima y=a + bx1 + cx2 + e
# regresyon cizcigisi best line, cizginin altindaki ve üstündeki degerlerin tolami sifir olur.
# Out:
# <img src="data:image/png;base64,..." width="899.7333333333333">

# %% [markdown]
# # Hue

# %%
# %matplotlib notebook
plt.figure(figsize = (12,7))
sns.scatterplot(y = "tip", data = tips, hue="day", x = "total_bill");
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
plt.figure(figsize = (12,7))
sns.scatterplot(y = "tip", data = tips, hue="sex", x = "total_bill");
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
plt.figure(figsize = (12,7))
sns.scatterplot(y = "tip", data = tips, hue="smoker", x = "total_bill");
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# # Style

# %%
# %matplotlib notebook
plt.figure(figsize = (12,7))
sns.scatterplot(y = "tip", data = tips, x = "total_bill", style = "day");

# %%
# %matplotlib notebook
plt.figure(figsize = (12,7))
sns.scatterplot(y = "tip", data = tips, hue="day", x = "total_bill", style = "smoker");
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
plt.figure(figsize=(9,5))
sns.scatterplot(data=tips, x = "total_bill", y = "tip", hue = "sex", style="day",);
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ![image.png](attachment:image.png)
