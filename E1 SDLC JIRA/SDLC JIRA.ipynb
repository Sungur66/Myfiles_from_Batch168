# %% [markdown]
# # SDLC
#
# Software Development Life Cycle (yazilim gelistirme yasam döngüsü)
#
# Bir programin baslangicindan müsteriye ulastirildigi ana kadarki sürec
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
