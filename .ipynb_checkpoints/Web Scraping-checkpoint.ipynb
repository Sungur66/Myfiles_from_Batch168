# %% [markdown]
# # Web Scraping
#
# Web Scraping - Veri kazima
#
# Bir kurulus veya pek cok kisinin cesitli nedenlerle internetten veri toplamasi gerekebilir.
#
# Pazarlama ve satis sirtketleri kullanabilir veya emlak, otel bilgilerine ulasma veya e-ticaret sitelerinin ürün karsilastirma icin kullandiklari bilgi cekme programi.
#
# Zorluklari:
# Programlama dillerinin farkli olmasi
# Sitelerdeki degiskenlikler takip edilmeli
# Web scraping yazmak yasal ama baska sitelerin bilgilerinin kullanilmasi ??
#
# Phyton da webscraping: (Requests or Beautifulsoup)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install requests
# Out:
# ...
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/a2/a0/4af29e22cb5942488cf45630cbdd7cefd908768e69bdd90280842e4e8529/charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/64/62/428ef076be88fa93716b576e4a01f919d25968913e817077a386fcbe4f42/certifi-2023.11.17-py3-none-any.whl.metadata
# ...
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...

# %%
import requests

# %%
requests?

# %%
url = "https://dummyjson.com/products"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import json

# %%
print(response.text)
# Out:
# {"products":[{"id":1,"title":"iPhone 9","description":"An apple mobile which is nothing like apple","price":549,"discountPercentage":12.96,"rating":4.69,"stock":94,"brand":"Apple","category":"smartphones","thumbnail":"https://i.dummyjson.com/data/products/1/thumbnail.jpg","images":["https://i.dummyjson.com/data/products/1/1.jpg","https://i.dummyjson.com/data/products/1/2.jpg","https://i.dummyjson.com/data/products/1/3.jpg","https://i.dummyjson.com/data/products/1/4.jpg","https://i.dummyjson.com/data/products/1/thumbnail.jpg"]},{"id":2,"title":"iPhone X","description":"SIM-Free, Model A19211 6.5-inch Super Retina HD display with OLED technology A12 Bionic chip with ...","price":899,"discountPercentage":17.94,"rating":4.44,"stock":34,"brand":"Apple","category":"smartphones","thumbnail":"https://i.dummyjson.com/data/products/2/thumbnail.jpg","images":["https://i.dummyjson.com/data/products/2/1.jpg","https://i.dummyjson.com/data/products/2/2.jpg","https://i.dummyjson.com/data/products/2/
# ...

# %%
products = json.loads(response.text)
products
# Out:
# {'products': [{'id': 1,
#    'title': 'iPhone 9',
#    'description': 'An apple mobile which is nothing like apple',
#    'price': 549,
#    'discountPercentage': 12.96,
#    'rating': 4.69,
#    'stock': 94,
#    'brand': 'Apple',
#    'category': 'smartphones',
#    'thumbnail': 'https://i.dummyjson.com/data/products/1/thumbnail.jpg',
#    'images': ['https://i.dummyjson.com/data/products/1/1.jpg',
#     'https://i.dummyjson.com/data/products/1/2.jpg',
#     'https://i.dummyjson.com/data/products/1/3.jpg',
#     'https://i.dummyjson.com/data/products/1/4.jpg',
#     'https://i.dummyjson.com/data/products/1/thumbnail.jpg']},
#   {'id': 2,
#    'title': 'iPhone X',
#    'description': 'SIM-Free, Model A19211 6.5-inch Super Retina HD display with OLED technology A12 Bionic chip with ...',
#    'price': 899,
#    'discountPercentage': 17.94,
#    'rating': 4.44,
#    'stock': 34,
#    'brand': 'Apple',
#    'category': 'smartphones',
# ...

# %%
print(products["products"])
# Out:
# [{'id': 1, 'title': 'iPhone 9', 'description': 'An apple mobile which is nothing like apple', 'price': 549, 'discountPercentage': 12.96, 'rating': 4.69, 'stock': 94, 'brand': 'Apple', 'category': 'smartphones', 'thumbnail': 'https://i.dummyjson.com/data/products/1/thumbnail.jpg', 'images': ['https://i.dummyjson.com/data/products/1/1.jpg', 'https://i.dummyjson.com/data/products/1/2.jpg', 'https://i.dummyjson.com/data/products/1/3.jpg', 'https://i.dummyjson.com/data/products/1/4.jpg', 'https://i.dummyjson.com/data/products/1/thumbnail.jpg']}, {'id': 2, 'title': 'iPhone X', 'description': 'SIM-Free, Model A19211 6.5-inch Super Retina HD display with OLED technology A12 Bionic chip with ...', 'price': 899, 'discountPercentage': 17.94, 'rating': 4.44, 'stock': 34, 'brand': 'Apple', 'category': 'smartphones', 'thumbnail': 'https://i.dummyjson.com/data/products/2/thumbnail.jpg', 'images': ['https://i.dummyjson.com/data/products/2/1.jpg', 'https://i.dummyjson.com/data/products/2/2.jpg', 'htt
# ...

# %%
products = products["products"]

for product in products:
    print(product["title"])
# Out:
# iPhone 9
# iPhone X
# Samsung Universe 9
# OPPOF19
# Huawei P30
# MacBook Pro
# Samsung Galaxy Book
# Microsoft Surface Laptop 4
# Infinix INBOOK
# HP Pavilion 15-DK1056WM
# perfume Oil
# Brown Perfume
# Fog Scent Xpressio Perfume
# Non-Alcoholic Concentrated Perfume Oil
# Eau De Perfume Spray
# Hyaluronic Acid Serum
# Tree Oil 30ml
# Oil Free Moisturizer 100ml
# Skin Beauty Serum.
# Freckle Treatment Cream- 15gm
# - Daal Masoor 500 grams
# Elbow Macaroni - 400 gm
# Orange Essence Food Flavou
# cereals muesli fruit nuts
# Gulab Powder 50 Gram
# Plant Hanger For Home
# Flying Wooden Bird
# 3D Embellishment Art Lamp
# Handcraft Chinese style
# Key Holder

# %% [markdown]
# **alacagimiz veriyi sinirlama**

# %%
url = "https://dummyjson.com/products"

response = requests.get(url, params={'limit':15, 'skip':20})
             # bu sekilde filtreleme yapiyoruz
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {"products":[{"id":21,"title":"- Daal Masoor 500 grams","description":"Fine quality Branded Product Keep in a cool and dry place","price":20,"discountPercentage":4.81,"rating":4.44,"stock":133,"brand":"Saaf & Khaas","category":"groceries","thumbnail":"https://i.dummyjson.com/data/products/21/thumbnail.png","images":["https://i.dummyjson.com/data/products/21/1.png","https://i.dummyjson.com/data/products/21/2.jpg","https://i.dummyjson.com/data/products/21/3.jpg"]},{"id":22,"title":"Elbow Macaroni - 400 gm","description":"Product details of Bake Parlor Big Elbow Macaroni - 400 gm","price":14,"discountPercentage":15.58,"rating":4.57,"stock":146,"brand":"Bake Parlor Big","category":"groceries","thumbnail":"https://i.dummyjson.com/data/products/22/thumbnail.jpg","images":["https://i.dummyjson.com/data/products/22/1.jpg","https://i.dummyjson.com/data/products/22/2.jpg","https://i.dummyjson.com/data/products/22/3.jpg"]},{"id":23,"title":"Orange Essence Food Flavou","description":"Specificati
# ...

# %%
products = json.loads(response.text)
products
# Out:
# {'products': [{'id': 21,
#    'title': '- Daal Masoor 500 grams',
#    'description': 'Fine quality Branded Product Keep in a cool and dry place',
#    'price': 20,
#    'discountPercentage': 4.81,
#    'rating': 4.44,
#    'stock': 133,
#    'brand': 'Saaf & Khaas',
#    'category': 'groceries',
#    'thumbnail': 'https://i.dummyjson.com/data/products/21/thumbnail.png',
#    'images': ['https://i.dummyjson.com/data/products/21/1.png',
#     'https://i.dummyjson.com/data/products/21/2.jpg',
#     'https://i.dummyjson.com/data/products/21/3.jpg']},
#   {'id': 22,
#    'title': 'Elbow Macaroni - 400 gm',
#    'description': 'Product details of Bake Parlor Big Elbow Macaroni - 400 gm',
#    'price': 14,
#    'discountPercentage': 15.58,
#    'rating': 4.57,
#    'stock': 146,
#    'brand': 'Bake Parlor Big',
#    'category': 'groceries',
#    'thumbnail': 'https://i.dummyjson.com/data/products/22/thumbnail.jpg',
#    'images': ['https://i.dummyjson.com/data/products/22/1.jpg',
# ...

# %%
products = json.loads(response.text)

for product in products['products']:
    print(f"urun title: {product['title']} -- urun fiyat:{product['price']} --  urun idsi:{product['id']}")
# Out:
# urun title: - Daal Masoor 500 grams -- urun fiyat:20 --  urun idsi:21
# urun title: Elbow Macaroni - 400 gm -- urun fiyat:14 --  urun idsi:22
# urun title: Orange Essence Food Flavou -- urun fiyat:14 --  urun idsi:23
# urun title: cereals muesli fruit nuts -- urun fiyat:46 --  urun idsi:24
# urun title: Gulab Powder 50 Gram -- urun fiyat:70 --  urun idsi:25
# urun title: Plant Hanger For Home -- urun fiyat:41 --  urun idsi:26
# urun title: Flying Wooden Bird -- urun fiyat:51 --  urun idsi:27
# urun title: 3D Embellishment Art Lamp -- urun fiyat:20 --  urun idsi:28
# urun title: Handcraft Chinese style -- urun fiyat:60 --  urun idsi:29
# urun title: Key Holder -- urun fiyat:30 --  urun idsi:30
# urun title: Mornadi Velvet Bed -- urun fiyat:40 --  urun idsi:31
# urun title: Sofa for Coffe Cafe -- urun fiyat:50 --  urun idsi:32
# urun title: 3 Tier Corner Shelves -- urun fiyat:700 --  urun idsi:33
# urun title: Plastic Table -- urun fiyat:50 --  urun idsi:34
# ...

# %%
response = requests.get(url, params={'limit':15, 'skip':20})

products = response.json()
print(products['products'])   # bu sekilde de kisa olusturabiliriz
# Out:
# [{'id': 21, 'title': '- Daal Masoor 500 grams', 'description': 'Fine quality Branded Product Keep in a cool and dry place', 'price': 20, 'discountPercentage': 4.81, 'rating': 4.44, 'stock': 133, 'brand': 'Saaf & Khaas', 'category': 'groceries', 'thumbnail': 'https://i.dummyjson.com/data/products/21/thumbnail.png', 'images': ['https://i.dummyjson.com/data/products/21/1.png', 'https://i.dummyjson.com/data/products/21/2.jpg', 'https://i.dummyjson.com/data/products/21/3.jpg']}, {'id': 22, 'title': 'Elbow Macaroni - 400 gm', 'description': 'Product details of Bake Parlor Big Elbow Macaroni - 400 gm', 'price': 14, 'discountPercentage': 15.58, 'rating': 4.57, 'stock': 146, 'brand': 'Bake Parlor Big', 'category': 'groceries', 'thumbnail': 'https://i.dummyjson.com/data/products/22/thumbnail.jpg', 'images': ['https://i.dummyjson.com/data/products/22/1.jpg', 'https://i.dummyjson.com/data/products/22/2.jpg', 'https://i.dummyjson.com/data/products/22/3.jpg']}, {'id': 23, 'title': 'Orange Essence 
# ...

# %% [markdown]
# Example

# %%
class Product:
    def __init__(self) ->None:
        self.url = "https://dummyjson.com/products"
        
    def get_all_product(self):
        response = requests.get(self.url)
        products = response.json() # kisa kullanim
#         products = response.text
#         products = json.loads(products)    uzun kullanim
        return products
    
    def get_single_product(self, product_id):
        response = requests.get(f"{self.url}/{product_id}")
        product = response.json()
        return product        
        
           
    # https://dummyjson.com/products/search?q=phone
    def search_product(self, name):
        pyload ={'q':name}
        response = requests.get(f"{self.url}/search/", params=pyload)
        products = response.json()
        return products 
    
     # https://dummyjson.com/products?limit=10&skip=10&select=title,price
    def search_product1(self, limit, skip, select):
        pyload ={'limit':limit, 'skip':skip, 'select':select}
        response = requests.get(f"{self.url}", params=pyload)
        return response.json()

product = Product()
print(product.get_all_product())
print('- - - - - - - - - - - - - - - - - - - - - - - - - -')
print(product.get_single_product(2))
print('- - - - - - - - - - - - - - - - - - - - - - - - - -')
print(product.search_product('phone'))
print('- - - - - - - - - - - - - - - - - - - - - - - - - -')
print(product.search_product1(10, 10, 'title'))
# Out:
# {'products': [{'id': 1, 'title': 'iPhone 9', 'description': 'An apple mobile which is nothing like apple', 'price': 549, 'discountPercentage': 12.96, 'rating': 4.69, 'stock': 94, 'brand': 'Apple', 'category': 'smartphones', 'thumbnail': 'https://i.dummyjson.com/data/products/1/thumbnail.jpg', 'images': ['https://i.dummyjson.com/data/products/1/1.jpg', 'https://i.dummyjson.com/data/products/1/2.jpg', 'https://i.dummyjson.com/data/products/1/3.jpg', 'https://i.dummyjson.com/data/products/1/4.jpg', 'https://i.dummyjson.com/data/products/1/thumbnail.jpg']}, {'id': 2, 'title': 'iPhone X', 'description': 'SIM-Free, Model A19211 6.5-inch Super Retina HD display with OLED technology A12 Bionic chip with ...', 'price': 899, 'discountPercentage': 17.94, 'rating': 4.44, 'stock': 34, 'brand': 'Apple', 'category': 'smartphones', 'thumbnail': 'https://i.dummyjson.com/data/products/2/thumbnail.jpg', 'images': ['https://i.dummyjson.com/data/products/2/1.jpg', 'https://i.dummyjson.com/data/products/2
# ...
