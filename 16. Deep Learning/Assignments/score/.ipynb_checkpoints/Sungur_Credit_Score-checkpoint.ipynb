# %% [markdown]
# <p style="background-color:#3ab1c8;font-family:Cursive;font-size:200%;color:black;text-align:center;border-radius:120px 20px;padding:20px;margin:20px;"><b>Capstone_Project_Credit_Score</b></p>
#
# <p style="font-family:Cursive;font-size:100%;color:black;text-align:center;border-radius:10px 10px;"><b>by Nash</b></p>
#
# <b style="font-family:Cursive;font-size:100%;color:black;text-align:right;border-radius:10px 10px;">Follow me [Linkedin](www.linkedin.com/in/nash-n-sungur-333869289) | [Git Hub](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0)</b>

# %% [markdown]
# # Welcome
#
# In this project, a predictive deep learning model will be created. In order for the model to give accurate and proper results, first the data and features will be checked, the application of EDA processes.
#
# Then, a model for Multi-Class Classification will be created and the results will be evaluated. After some adjustments to get better results, the model will be deployed as the "final model".
#
# Please take a look at the findings and tasks before diving into the project.

# %% [markdown]
# ## Import  libraries & data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12, 6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv("Score.csv")
df.head()
# Out:
#    Delay_from_due_date  Num_of_Delayed_Payment  Num_Credit_Inquiries  \
# 0                3.000                   7.000                 4.000
# 1                3.000                   7.000                 4.000
# 2                3.000                   7.000                 4.000
# 3                5.000                   4.000                 4.000
# 4                6.000                   4.000                 4.000
#
#    Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 0                    26.823             265.000                    No
# 1                    31.945             265.000                    No
# 2                    28.609             267.000                    No
# 3                    31.378             268.000                    No
# 4                    24.797             269.000                    No
#
#    Amount_invested_monthly  Monthly_Balance Credit_Score Credit_Mix  ...  \
# 0                   80.415          312.494         Good       Good  ...
# 1                  118.280          284.629         Good       Good  ...
# 2                   81.700          331.210         Good       Good  ...
# 3                  199.458          223.451         Good       Good  ...
# 4                   41.420          341.489         Good       Good  ...
#
#      Age  Annual_Income  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0 23.000      19114.120              3.000            4.000          3.000
# 1 23.000      19114.120              3.000            4.000          3.000
# 2 23.000      19114.120              3.000            4.000          3.000
# 3 23.000      19114.120              3.000            4.000          3.000
# 4 23.000      19114.120              3.000            4.000          3.000
#
#    Num_of_Loan  Monthly_Inhand_Salary  Changed_Credit_Limit  Outstanding_Debt  \
# 0        4.000               1824.843                11.270           809.980
# 1        4.000               1824.843                11.270           809.980
# 2        4.000               1824.843                11.270           809.980
# 3        4.000               1824.843                11.270           809.980
# 4        4.000               1824.843                11.270           809.980
#
#    Total_EMI_per_month
# 0               49.575
# 1               49.575
# 2               49.575
# 3               49.575
# 4               49.575
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99960 entries, 0 to 99959
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Delay_from_due_date       99960 non-null  float64
#  1   Num_of_Delayed_Payment    99960 non-null  float64
#  2   Num_Credit_Inquiries      99960 non-null  float64
#  3   Credit_Utilization_Ratio  99960 non-null  float64
#  4   Credit_History_Age        99960 non-null  float64
#  5   Payment_of_Min_Amount     99960 non-null  object
#  6   Amount_invested_monthly   99960 non-null  float64
#  7   Monthly_Balance           99960 non-null  float64
#  8   Credit_Score              99960 non-null  object
#  9   Credit_Mix                99960 non-null  object
#  10  Payment_Behaviour         99960 non-null  object
#  11  Age                       99960 non-null  float64
#  12  Annual_Income             99960 non-null  float64
#  13  Num_Bank_Accounts         99960 non-null  float64
#  14  Num_Credit_Card           99960 non-null  float64
#  15  Interest_Rate             99960 non-null  float64
#  16  Num_of_Loan               99960 non-null  float64
#  17  Monthly_Inhand_Salary     99960 non-null  float64
#  18  Changed_Credit_Limit      99960 non-null  float64
#  19  Outstanding_Debt          99960 non-null  float64
#  20  Total_EMI_per_month       99960 non-null  float64
# dtypes: float64(17), object(4)
# memory usage: 16.0+ MB

# %% [markdown]
# # Determines
#
# **Delay_from_due_date:** It refers to the delay between the payment date and the overdue date. This delay indicates how many days the payment is made after the due date.
#
# **Num_of_Delayed_Payment:** It represents the number of past due payments for a particular account or customer. This feature indicates how often the customer makes payments after maturity.
#
# **Num_Credit_Inquiries:** It shows the number of credit inquiries made during a specific time period regarding the credit history of a particular customer or account. This feature refers to the number of queries made about the customer's credit history.
#
# **Credit_Utilization_Ratio:** It expresses the amount of credit used by a customer as a percentage based on his or her existing credit limits. This ratio shows the customer's credit usage habits by comparing the customer's current credit usage to the current credit limit. For example, if a customer's credit limit is 10,000 TL and this customer used a loan of 2,000 TL, the credit utilization rate will be 20%.
#
# **Credit_History_Age:** How long a customer's credit history is can be an indicator of their credit history and financial history. A longer credit history can often have a positive impact on credit score and credit risk assessments.
#
# **Payment_of_Min_Amount:** It is a feature that shows whether a customer has paid the minimum payment amount of his credit card or loan debt. This feature provides insight into the customer's payment habits and debt management.
#
# **Amount_invested_monthly:** It refers to the amount of investment made by a customer in a particular month. This feature shows how much the customer invests monthly. Investment amounts can often include investments in different financial instruments (stocks, bonds, funds, etc.) and provide information about the client's savings and investment habits.
#
# **Monthly_Balance:** It shows the remaining balance of a particular customer or account at the end of each month in the account during that month. This feature provides information about the financial status of the account over a specific period and gives insight into factors such as the customer's income-expense balance, spending habits or savings tendencies.
# **Credit_Score:** It is a numerical score determined by evaluating factors such as a customer's credit history, payment habits, debts and financial situation. This score is an important metric that lenders use when evaluating their customers.
#
# **Credit_Mix:** Credit diversity is important to a credit score because a balanced use of different types of credit (e.g., credit cards, mortgages) diversifies credit history and payment habits, which can create a higher credit score.
#
# **Payment_Behaviour:** Payment habit is a critical factor in determining credit score. While regular payments support a high credit score, delays or missing payments can negatively impact your credit score.
#
# **Age:** Age can affect credit score because it is often associated with a longer credit history and financial experience. A history of long-term, regular payments can often result in a higher credit score.
#
# **Annual_Income:** Annual income is important in credit score evaluation because income level can reflect a person's ability to pay. Higher income can often indicate more credit and better ability to pay.
#
# **Num_Bank_Accounts:** Multiple bank accounts can show financial stability and diversification, which can positively impact your credit score. Relationship with different financial institutions can help establish credit history.
#
# **Num_of_Delayed_Payment:** It represents the number of past due payments for a particular account or customer. This feature indicates how often the customer makes payments after maturity.
#
# **Num_Credit_Card:** Having more than one credit card can affect your credit score because it can be associated with factors such as varying credit usage and increasing limits.
#
# **Interest_Rate:** The interest rates applied are especially important in terms of regularity and convenience in loan payments. Lower interest rates mean easier payments and lower costs, which can positively impact your credit score.
#
# **Num_of_Loan:** Multiple loans or debts may reflect payment habits and debt management. However, excessive borrowing can create a risky situation and reduce your credit score.
#
# **Monthly_Inhand_Salary:** The amount of monthly net income indicates the payment capacity and affects the ability to pay off debts. Higher income is generally associated with a better credit score.
#
# **Changed_Credit_Limit:** Changes to the credit limit can reveal a customer's credit usage habits and credit requests, which can affect their credit score.
#
# **Outstanding_Debt:** Unpaid debts can negatively impact your credit score, especially when compared to your credit limit. High debts can increase credit risk.
#
# **Total_EMI_per_month:** The monthly installment amount indicates the client's ability to manage his debts. High installment payments may strain payment capacity and reduce credit score.

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.shape
# Out:
# (99960, 21)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                              count      mean       std      min       25%  \
# Delay_from_due_date      99960.000    21.096    14.827    0.000    10.000
# Num_of_Delayed_Payment   99960.000    13.336     6.270    0.000     9.000
# Num_Credit_Inquiries     99960.000     5.775     3.862    0.000     3.000
# Credit_Utilization_Ratio 99960.000    32.285     5.117   20.000    28.052
# Credit_History_Age       99960.000   221.123    99.696    1.000   144.000
# Amount_invested_monthly  99960.000   193.665   194.783    0.000    73.709
# Monthly_Balance          99960.000   403.445   214.387    0.008   270.317
# Age                      99960.000    33.269    10.762   14.000    24.000
# Annual_Income            99960.000 50498.704 38294.243 7005.930 19338.480
# Num_Bank_Accounts        99960.000     5.369     2.592    0.000     3.000
# Num_Credit_Card          99960.000     5.533     2.068    0.000     4.000
# Interest_Rate            99960.000    14.535     8.741    1.000     7.000
# Num_of_Loan              99960.000     3.534     2.446    0.000     2.000
# Monthly_Inhand_Salary    99960.000  4196.814  3186.518  303.645  1626.594
# Changed_Credit_Limit     99960.000    10.397     6.511    0.500     5.500
# Outstanding_Debt         99960.000  1426.515  1155.253    0.230   566.080
# Total_EMI_per_month      99960.000   105.566   125.821    0.000    29.054
#
#                                50%       75%        max
# Delay_from_due_date         18.000    28.000     67.000
# Num_of_Delayed_Payment      14.000    18.000     28.000
# Num_Credit_Inquiries         5.000     8.000     29.000
# Credit_Utilization_Ratio    32.305    36.496     50.000
# Credit_History_Age         219.000   302.000    404.000
# Amount_invested_monthly    129.342   234.324   1977.326
# Monthly_Balance            337.238   471.905   1602.041
# Age                         33.000    42.000     56.000
# Annual_Income            36996.830 71681.400 179987.280
# Num_Bank_Accounts            5.000     7.000     10.000
# Num_Credit_Card              5.000     7.000     11.000
# Interest_Rate               13.000    20.000     34.000
# Num_of_Loan                  3.000     5.000      9.000
# Monthly_Inhand_Salary     3091.387  5957.715  15204.633
# Changed_Credit_Limit         9.340    14.680     29.980
# Outstanding_Debt          1166.470  1948.200   4998.070
# Total_EMI_per_month         66.058   145.585   1779.103

# %%
print(df.Credit_Score.value_counts())
sns.countplot(df["Credit_Score"]);      # unbalanced
# Out:
# Standard    53149
# Poor        28988
# Good        17823
# Name: Credit_Score, dtype: int64

# %%
df.hist(figsize=(15, 12), bins=15);

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True, cmap='viridis');

# %%
df.drop(['Annual_Income'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
encoded_columns = encoder.fit_transform(df[['Credit_Score', 'Payment_of_Min_Amount','Credit_Mix', 'Payment_Behaviour']])

df[['Credit_Score', 'Payment_of_Min_Amount','Credit_Mix', 'Payment_Behaviour']] = encoded_columns

df.head()
# Out:
#    Delay_from_due_date  Num_of_Delayed_Payment  Num_Credit_Inquiries  \
# 0                3.000                   7.000                 4.000
# 1                3.000                   7.000                 4.000
# 2                3.000                   7.000                 4.000
# 3                5.000                   4.000                 4.000
# 4                6.000                   4.000                 4.000
#
#    Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  \
# 0                    26.823             265.000                  1.000
# 1                    31.945             265.000                  1.000
# 2                    28.609             267.000                  1.000
# 3                    31.378             268.000                  1.000
# 4                    24.797             269.000                  1.000
#
#    Amount_invested_monthly  Monthly_Balance  Credit_Score  Credit_Mix  \
# 0                   80.415          312.494         0.000       1.000
# 1                  118.280          284.629         0.000       1.000
# 2                   81.700          331.210         0.000       1.000
# 3                  199.458          223.451         0.000       1.000
# 4                   41.420          341.489         0.000       1.000
#
#    Payment_Behaviour    Age  Num_Bank_Accounts  Num_Credit_Card  \
# 0              1.000 23.000              3.000            4.000
# 1              1.000 23.000              3.000            4.000
# 2              1.000 23.000              3.000            4.000
# 3              1.000 23.000              3.000            4.000
# 4              1.000 23.000              3.000            4.000
#
#    Interest_Rate  Num_of_Loan  Monthly_Inhand_Salary  Changed_Credit_Limit  \
# 0          3.000        4.000               1824.843                11.270
# 1          3.000        4.000               1824.843                11.270
# 2          3.000        4.000               1824.843                11.270
# 3          3.000        4.000               1824.843                11.270
# 4          3.000        4.000               1824.843                11.270
#
#    Outstanding_Debt  Total_EMI_per_month
# 0           809.980               49.575
# 1           809.980               49.575
# 2           809.980               49.575
# 3           809.980               49.575
# 4           809.980               49.575

# %%
df.corr()['Credit_Score'][:-1].sort_values().plot.barh();

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True, cmap='viridis');

# %% [markdown]
# ## Preprocessing of Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('Credit_Score', axis=1).values
y = df['Credit_Score'].values
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Modelling & Model Performance

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score

from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(units=128, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=64, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=32, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=16, activation="tanh"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=8, activation="tanh"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=3, activation="softmax"))

opt = Adam(learning_rate=0.002)

model.compile(optimizer=opt, 
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"],
             run_eagerly=True)

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=50)

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1], 2: class_weights[2]}
class_weights
# Out:
# {0: 1.8694595100056106, 1: 1.1494499597531527, 2: 0.6269180917339131}

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=0.1,
          batch_size=32,
          epochs=500,
          verbose=1,
          callbacks=[early_stop],
          class_weight=class_weights)
# Out:
# Epoch 1/500
# 2531/2531 [==============================] - 210s 83ms/step - loss: 0.9082 - accuracy: 0.4891 - val_loss: 0.8682 - val_accuracy: 0.5826
# Epoch 2/500
# 2531/2531 [==============================] - 208s 82ms/step - loss: 0.8449 - accuracy: 0.5775 - val_loss: 0.8233 - val_accuracy: 0.6310
# Epoch 3/500
# 2531/2531 [==============================] - 208s 82ms/step - loss: 0.8288 - accuracy: 0.5951 - val_loss: 0.8575 - val_accuracy: 0.6095
# Epoch 4/500
# 2531/2531 [==============================] - 208s 82ms/step - loss: 0.8177 - accuracy: 0.6027 - val_loss: 0.7842 - val_accuracy: 0.6527
# Epoch 5/500
# 2531/2531 [==============================] - 208s 82ms/step - loss: 0.8109 - accuracy: 0.6060 - val_loss: 0.9351 - val_accuracy: 0.5400
# Epoch 6/500
#  868/2531 [=========>....................] - ETA: 2:20 - loss: 0.8076 - accuracy: 0.6076
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6484\1212574825.py in ?()
# ----> 1 model.fit(x=X_train,
#       2           y=y_train,
#       3           validation_split=0.1,
#       4           batch_size=32,
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1803                             batch_size=batch_size,
#    1804                             _r=1,
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#    1810                             # No error, now safe to assign to logs.
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\training.py in ?(iterator)
#    1399             def train_function(iterator):
#    1400                 """Runs a training execution with a single step."""
# -> 1401                 return step_function(self, iterator)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\training.py in ?(model, iterator)
#    1380                 run_step = tf.function(
#    1381                     run_step, jit_compile=True, reduce_retracing=True
#    1382                 )
#    1383             data = next(iterator)
# -> 1384             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1385             outputs = reduce_per_replica(
#    1386                 outputs,
#    1387                 self.distribute_strategy,
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(***failed resolving arguments***)
#    1677       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678       # applied when the caller is also in Eager mode.
#    1679       fn = autograph.tf_convert(
#    1680           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    3267     _require_cross_replica_or_default_context_extended(self)
#    3268     if kwargs is None:
#    3269       kwargs = {}
#    3270     with self._container_strategy().scope():
# -> 3271       return self._call_for_each_replica(fn, args, kwargs)
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    4067   def _call_for_each_replica(self, fn, args, kwargs):
#    4068     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069       return fn(*args, **kwargs)
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     594   def wrapper(*args, **kwargs):
#     595     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596       return func(*args, **kwargs)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\training.py in ?(data)
#    1372             def run_step(data):
# -> 1373                 outputs = model.train_step(data)
#    1374                 # Ensure counter is updated only if `train_step` succeeds.
#    1375                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#    1376                     model._train_counter.assign_add(1)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\training.py in ?(self, data)
#    1146         """
#    1147         x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
#    1148         # Run forward pass.
#    1149         with tf.GradientTape() as tape:
# -> 1150             y_pred = self(x, training=True)
#    1151             loss = self.compute_loss(x, y, y_pred, sample_weight)
#    1152         self._validate_target_and_loss(y, loss)
#    1153         # Run backwards pass.
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\training.py in ?(self, *args, **kwargs)
#     586                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     587
#     588             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     589
# --> 590         return super().__call__(*args, **kwargs)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1145
#    1146                 with autocast_variable.enable_auto_cast_variables(
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#    1152                     self._handle_activity_regularization(inputs, outputs)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\sequential.py in ?(self, inputs, training, mask)
#     394
#     395         if self._graph_initialized:
#     396             if not self.built:
#     397                 self._init_graph_network(self.inputs, self.outputs)
# --> 398             return super().call(inputs, training=training, mask=mask)
#     399
#     400         outputs = inputs  # handle the corner case where self.layers is empty
#     401         for layer in self.layers:
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\functional.py in ?(self, inputs, training, mask)
#     511         Returns:
#     512             A tensor if there is a single output, or
#     513             a list of tensors if there are more than one outputs.
#     514         """
# --> 515         return self._run_internal_graph(inputs, training=training, mask=mask)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\functional.py in ?(self, inputs, training, mask)
#     668                 if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     669                     continue  # Node is not computable, try skipping.
#     670
#     671                 args, kwargs = node.map_arguments(tensor_dict)
# --> 672                 outputs = node.layer(*args, **kwargs)
#     673
#     674                 # Update tensor_dict.
#     675                 for x_id, y in zip(
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1145
#    1146                 with autocast_variable.enable_auto_cast_variables(
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#    1152                     self._handle_activity_regularization(inputs, outputs)
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\layers\regularization\dropout.py in ?(self, inputs, training)
#     116             return self._random_generator.dropout(
#     117                 inputs, self.rate, noise_shape=self._get_noise_shape(inputs)
#     118             )
#     119
# --> 120         output = control_flow_util.smart_cond(
#     121             training, dropped_inputs, lambda: tf.identity(inputs)
#     122         )
#     123         return output
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\control_flow_util.py in ?(pred, true_fn, false_fn, name)
#     104       TypeError: If `true_fn` or `false_fn` is not callable.
#     105     """
#     106     if isinstance(pred, tf.Variable):
#     107         return tf.cond(pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 108     return tf.__internal__.smart_cond.smart_cond(
#     109         pred, true_fn=true_fn, false_fn=false_fn, name=name
#     110     )
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\framework\smart_cond.py in ?(pred, true_fn, false_fn, name)
#      49
#      50   pred_value = smart_constant_value(pred)
#      51   if pred_value is not None:
#      52     if pred_value:
# ---> 53       return true_fn()
#      54     else:
#      55       return false_fn()
#      56   else:
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\layers\regularization\dropout.py in ?()
#     115         def dropped_inputs():
# --> 116             return self._random_generator.dropout(
#     117                 inputs, self.rate, noise_shape=self._get_noise_shape(inputs)
#     118             )
#
# ~\.conda\envs\myenv\lib\site-packages\keras\src\backend.py in ?(self, inputs, rate, noise_shape)
#    2166                 noise_shape=noise_shape,
#    2167                 seed=self.make_seed_for_stateless_op(),
#    2168             )
#    2169         else:
# -> 2170             return tf.nn.dropout(
#    2171                 inputs,
#    2172                 rate=rate,
#    2173                 noise_shape=noise_shape,
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(x, rate, noise_shape, seed, name)
#    5510   """
#    5511   uniform_sampler = functools.partial(random_ops.random_uniform, seed=seed)
#    5512   def dummy_rng_step():
#    5513     random_seed.get_seed(seed)
# -> 5514   return _dropout(x=x, rate=rate, noise_shape=noise_shape,
#    5515                   uniform_sampler=uniform_sampler,
#    5516                   dummy_rng_step=dummy_rng_step, name=name,
#    5517                   default_name="dropout")
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(x, rate, noise_shape, uniform_sampler, dummy_rng_step, name, default_name)
#    5783       if is_rate_number:
#    5784         keep_prob = 1 - rate
#    5785         scale = 1 / keep_prob
#    5786         scale = ops.convert_to_tensor(scale, dtype=x_dtype)
# -> 5787         ret = gen_math_ops.mul(x, scale)
#    5788       else:
#    5789         raise ValueError(
#    5790             f"`rate` must be a scalar or scalar tensor. Received: rate={rate}")
#
# ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#    6752         _ctx, "Mul", name, x, y)
#    6753       return _result
#    6754     except _core._NotOkStatusException as e:
#    6755       _ops.raise_from_not_ok_status(e, name)
# -> 6756     except _core._FallbackException:
#    6757       pass
#    6758     try:
#    6759       return mul_eager_fallback(
#
# KeyboardInterrupt:

# %%
dft = df.sample(10000, random_state=42)

Xt = dft.drop('Credit_Score', axis=1).values
yt = dft['Credit_Score'].values
seed = 42
Xt_train, Xt_test, yt_train, yt_test = train_test_split(Xt,
                                                    yt,
                                                    stratify=yt,
                                                    test_size=0.1,
                                                    random_state=seed)
scaler = MinMaxScaler()

Xt_train = scaler.fit_transform(Xt_train)
Xt_test = scaler.transform(Xt_test)

tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(units=128, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=64, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=32, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=16, activation="tanh"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=8, activation="tanh"))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(units=3, activation="softmax"))

opt = Adam(learning_rate=0.002)
model.compile(optimizer=opt, 
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"],
             run_eagerly=True)

early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=50)
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(yt_train),
                                                  y=yt_train)

class_weights = {0: class_weights[0], 1: class_weights[1], 2: class_weights[2]}
class_weights

model.fit(x=Xt_train,
          y=yt_train,
          validation_split=0.1,
          batch_size=32,
          epochs=500,
          verbose=1,
          callbacks=[early_stop],
          class_weight=class_weights)
# Out:
# Epoch 1/500
# WARNING:tensorflow:From C:\Users\nsgr6\.conda\envs\myenv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 254/254 [==============================] - 24s 92ms/step - loss: 0.9705 - accuracy: 0.5412 - val_loss: 0.8738 - val_accuracy: 0.5989
# Epoch 2/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.8356 - accuracy: 0.6133 - val_loss: 0.8030 - val_accuracy: 0.6522
# Epoch 3/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7981 - accuracy: 0.6412 - val_loss: 0.8117 - val_accuracy: 0.6589
# Epoch 4/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7914 - accuracy: 0.6440 - val_loss: 0.7970 - val_accuracy: 0.6567
# Epoch 5/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7855 - accuracy: 0.6535 - val_loss: 0.8156 - val_accuracy: 0.6522
# Epoch 6/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7736 - accuracy: 0.6544 - val_loss: 0.7887 - val_accuracy: 0.6611
# Epoch 7/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7717 - accuracy: 0.6538 - val_loss: 0.7826 - val_accuracy: 0.6622
# Epoch 8/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7799 - accuracy: 0.6559 - val_loss: 0.7954 - val_accuracy: 0.6567
# Epoch 9/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7699 - accuracy: 0.6569 - val_loss: 0.7706 - val_accuracy: 0.6733
# Epoch 10/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7740 - accuracy: 0.6599 - val_loss: 0.7842 - val_accuracy: 0.6567
# Epoch 11/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7696 - accuracy: 0.6619 - val_loss: 0.7812 - val_accuracy: 0.6689
# Epoch 12/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7645 - accuracy: 0.6579 - val_loss: 0.8018 - val_accuracy: 0.6667
# Epoch 13/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7681 - accuracy: 0.6630 - val_loss: 0.7832 - val_accuracy: 0.6611
# Epoch 14/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7674 - accuracy: 0.6612 - val_loss: 0.7896 - val_accuracy: 0.6611
# Epoch 15/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7634 - accuracy: 0.6664 - val_loss: 0.7811 - val_accuracy: 0.6689
# Epoch 16/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7654 - accuracy: 0.6626 - val_loss: 0.7729 - val_accuracy: 0.6711
# Epoch 17/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7622 - accuracy: 0.6604 - val_loss: 0.7785 - val_accuracy: 0.6700
# Epoch 18/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7643 - accuracy: 0.6626 - val_loss: 0.7734 - val_accuracy: 0.6744
# Epoch 19/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7626 - accuracy: 0.6614 - val_loss: 0.8056 - val_accuracy: 0.6556
# Epoch 20/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7623 - accuracy: 0.6626 - val_loss: 0.8010 - val_accuracy: 0.6589
# Epoch 21/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7569 - accuracy: 0.6599 - val_loss: 0.7940 - val_accuracy: 0.6500
# Epoch 22/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7579 - accuracy: 0.6672 - val_loss: 0.7985 - val_accuracy: 0.6544
# Epoch 23/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7538 - accuracy: 0.6599 - val_loss: 0.7737 - val_accuracy: 0.6622
# Epoch 24/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7511 - accuracy: 0.6675 - val_loss: 0.7766 - val_accuracy: 0.6567
# Epoch 25/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7538 - accuracy: 0.6610 - val_loss: 0.7839 - val_accuracy: 0.6589
# Epoch 26/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7607 - accuracy: 0.6580 - val_loss: 0.7701 - val_accuracy: 0.6600
# Epoch 27/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7439 - accuracy: 0.6572 - val_loss: 0.7892 - val_accuracy: 0.6544
# Epoch 28/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7488 - accuracy: 0.6554 - val_loss: 0.7867 - val_accuracy: 0.6633
# Epoch 29/500
# 254/254 [==============================] - 24s 93ms/step - loss: 0.7509 - accuracy: 0.6605 - val_loss: 0.7777 - val_accuracy: 0.6578
# Epoch 30/500
# 254/254 [==============================] - 25s 97ms/step - loss: 0.7534 - accuracy: 0.6575 - val_loss: 0.7809 - val_accuracy: 0.6589
# Epoch 31/500
# 254/254 [==============================] - 27s 104ms/step - loss: 0.7526 - accuracy: 0.6577 - val_loss: 0.7838 - val_accuracy: 0.6622
# Epoch 32/500
# 254/254 [==============================] - 23s 92ms/step - loss: 0.7549 - accuracy: 0.6600 - val_loss: 0.8055 - val_accuracy: 0.6544
# Epoch 33/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7440 - accuracy: 0.6588 - val_loss: 0.7768 - val_accuracy: 0.6578
# Epoch 34/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7484 - accuracy: 0.6628 - val_loss: 0.7682 - val_accuracy: 0.6633
# Epoch 35/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7496 - accuracy: 0.6616 - val_loss: 0.7788 - val_accuracy: 0.6644
# Epoch 36/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7496 - accuracy: 0.6627 - val_loss: 0.7770 - val_accuracy: 0.6622
# Epoch 37/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7476 - accuracy: 0.6605 - val_loss: 0.7620 - val_accuracy: 0.6667
# Epoch 38/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7530 - accuracy: 0.6656 - val_loss: 0.7835 - val_accuracy: 0.6656
# Epoch 39/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7453 - accuracy: 0.6672 - val_loss: 0.7623 - val_accuracy: 0.6744
# Epoch 40/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7477 - accuracy: 0.6633 - val_loss: 0.7858 - val_accuracy: 0.6589
# Epoch 41/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7501 - accuracy: 0.6643 - val_loss: 0.7807 - val_accuracy: 0.6656
# Epoch 42/500
# 254/254 [==============================] - 23s 91ms/step - loss: 0.7438 - accuracy: 0.6721 - val_loss: 0.7751 - val_accuracy: 0.6700
# Epoch 43/500
# 254/254 [==============================] - 23s 92ms/step - loss: 0.7428 - accuracy: 0.6601 - val_loss: 0.8006 - val_accuracy: 0.6589
# Epoch 44/500
# 254/254 [==============================] - 24s 96ms/step - loss: 0.7462 - accuracy: 0.6607 - val_loss: 0.7636 - val_accuracy: 0.6600
# Epoch 45/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7361 - accuracy: 0.6665 - val_loss: 0.7831 - val_accuracy: 0.6589
# Epoch 46/500
# 254/254 [==============================] - 23s 90ms/step - loss: 0.7463 - accuracy: 0.6621 - val_loss: 0.7863 - val_accuracy: 0.6678
# Epoch 47/500
#  38/254 [===>..........................] - ETA: 19s - loss: 0.7402 - accuracy: 0.6702

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
y_pred = (model.predict(Xt_test) > 0.5).astype("int32")
print(confusion_matrix(yt_test, y_pred))
print(classification_report(yt_test, y_pred))

# %%
model.history.history

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 0s 2ms/step
# [[618 178]
#  [ 53 151]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84       796
#            1       0.46      0.74      0.57       204
#
#     accuracy                           0.77      1000
#    macro avg       0.69      0.76      0.70      1000
# weighted avg       0.83      0.77      0.79      1000

# %% [markdown]
# ![ROC.JPG](attachment:ROC.JPG)

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show();
# roc curve, sınıflandırma performansını gösterir

# %%
average_precision_score(y_test, y_pred_proba)   #0.692983743350624

# %% [markdown]
# ![model.jpeg](attachment:model.jpeg)

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle

pickle.dump(scaler, open("scaler_churn", 'wb'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scaler = MinMaxScaler().fit(X)

# %%
X_scaled = scaler.transform(X)

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.001)

model.compile(optimizer=opt,
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
model.fit(x=X_scaled,
          y=y,
          callbacks=[early_stop],
          batch_size=32,
          validation_split = 0.1,
          epochs=500,
          verbose=1,
          class_weight=class_weights)
# Out:
# Epoch 1/500
# 282/282 [==============================] - 4s 5ms/step - loss: 0.6950 - recall: 0.5716 - val_loss: 0.6297 - val_recall: 0.4860
# Epoch 2/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.6114 - recall: 0.6572 - val_loss: 0.5823 - val_recall: 0.6313
# Epoch 3/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5852 - recall: 0.6846 - val_loss: 0.5506 - val_recall: 0.6592
# Epoch 4/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5694 - recall: 0.7153 - val_loss: 0.5499 - val_recall: 0.7039
# Epoch 5/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5403 - recall: 0.7244 - val_loss: 0.5910 - val_recall: 0.7765
# Epoch 6/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5220 - recall: 0.7589 - val_loss: 0.5046 - val_recall: 0.6872
# Epoch 7/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5088 - recall: 0.7465 - val_loss: 0.4976 - val_recall: 0.7039
# Epoch 8/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5042 - recall: 0.7503 - val_loss: 0.5190 - val_recall: 0.7598
# Epoch 9/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4874 - recall: 0.7820 - val_loss: 0.4488 - val_recall: 0.6201
# Epoch 10/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4899 - recall: 0.7594 - val_loss: 0.5099 - val_recall: 0.7318
# Epoch 11/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4874 - recall: 0.7680 - val_loss: 0.5104 - val_recall: 0.7151
# Epoch 12/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4809 - recall: 0.7702 - val_loss: 0.4847 - val_recall: 0.6927
# Epoch 13/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4757 - recall: 0.7756 - val_loss: 0.4841 - val_recall: 0.6983
# Epoch 14/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4827 - recall: 0.7605 - val_loss: 0.5071 - val_recall: 0.7486
# Epoch 15/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4765 - recall: 0.7713 - val_loss: 0.5256 - val_recall: 0.7430
# Epoch 16/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4816 - recall: 0.7664 - val_loss: 0.4923 - val_recall: 0.6927
# Epoch 17/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4783 - recall: 0.7594 - val_loss: 0.5141 - val_recall: 0.7207
# Epoch 18/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4656 - recall: 0.7772 - val_loss: 0.5462 - val_recall: 0.7598
# Epoch 19/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4724 - recall: 0.7772 - val_loss: 0.4627 - val_recall: 0.7151
# Epoch 20/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4687 - recall: 0.7820 - val_loss: 0.4700 - val_recall: 0.7263
# Epoch 21/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4669 - recall: 0.7761 - val_loss: 0.4673 - val_recall: 0.6816
# Epoch 22/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4694 - recall: 0.7696 - val_loss: 0.5024 - val_recall: 0.6927
# Epoch 23/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4668 - recall: 0.7804 - val_loss: 0.4725 - val_recall: 0.6704
# Epoch 24/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4638 - recall: 0.7772 - val_loss: 0.5048 - val_recall: 0.7263
# Epoch 25/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4637 - recall: 0.7745 - val_loss: 0.4639 - val_recall: 0.6760
# Epoch 26/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4607 - recall: 0.7826 - val_loss: 0.5245 - val_recall: 0.7486
# Epoch 27/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4550 - recall: 0.7761 - val_loss: 0.4824 - val_recall: 0.6872
# Epoch 28/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4622 - recall: 0.7718 - val_loss: 0.4878 - val_recall: 0.7151
# Epoch 29/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4612 - recall: 0.7718 - val_loss: 0.4829 - val_recall: 0.7095
# Epoch 30/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4551 - recall: 0.7777 - val_loss: 0.5015 - val_recall: 0.7095
# Epoch 31/500
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4546 - recall: 0.7804 - val_loss: 0.4717 - val_recall: 0.6760
# Epoch 32/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4563 - recall: 0.7879 - val_loss: 0.4577 - val_recall: 0.6816
# Epoch 33/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4580 - recall: 0.7723 - val_loss: 0.5091 - val_recall: 0.7263
# Epoch 34/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4595 - recall: 0.7734 - val_loss: 0.5222 - val_recall: 0.7486
# Epoch 35/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4551 - recall: 0.7906 - val_loss: 0.4711 - val_recall: 0.6648
# Epoch 36/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4546 - recall: 0.7734 - val_loss: 0.5018 - val_recall: 0.7263
# Epoch 37/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4451 - recall: 0.7847 - val_loss: 0.4922 - val_recall: 0.7430
# Epoch 38/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4520 - recall: 0.7847 - val_loss: 0.4937 - val_recall: 0.7318
# Epoch 39/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4464 - recall: 0.7890 - val_loss: 0.5114 - val_recall: 0.7430
# Epoch 40/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4464 - recall: 0.7966 - val_loss: 0.4802 - val_recall: 0.6816
# Epoch 41/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4384 - recall: 0.7944 - val_loss: 0.4937 - val_recall: 0.6872
# Epoch 42/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4440 - recall: 0.7831 - val_loss: 0.5082 - val_recall: 0.7039
# Epoch 43/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4446 - recall: 0.7890 - val_loss: 0.4639 - val_recall: 0.6927
# Epoch 44/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4454 - recall: 0.7879 - val_loss: 0.4864 - val_recall: 0.6983
# Epoch 45/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4388 - recall: 0.7971 - val_loss: 0.4795 - val_recall: 0.7039
# Epoch 46/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4401 - recall: 0.7885 - val_loss: 0.4677 - val_recall: 0.6983
# Epoch 47/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4365 - recall: 0.7879 - val_loss: 0.4885 - val_recall: 0.7263
# Epoch 48/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4397 - recall: 0.7906 - val_loss: 0.5154 - val_recall: 0.7207
# Epoch 49/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4328 - recall: 0.8111 - val_loss: 0.4964 - val_recall: 0.7486
# Epoch 50/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4376 - recall: 0.8089 - val_loss: 0.4615 - val_recall: 0.6648
# Epoch 51/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4303 - recall: 0.7960 - val_loss: 0.4918 - val_recall: 0.7151
# Epoch 52/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4312 - recall: 0.8181 - val_loss: 0.4875 - val_recall: 0.7095
# Epoch 53/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4342 - recall: 0.8100 - val_loss: 0.4689 - val_recall: 0.7207
# Epoch 54/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4336 - recall: 0.7928 - val_loss: 0.4848 - val_recall: 0.7039
# Epoch 55/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4335 - recall: 0.7949 - val_loss: 0.5018 - val_recall: 0.6983
# Epoch 56/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4379 - recall: 0.7896 - val_loss: 0.5010 - val_recall: 0.7263
# Epoch 57/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4253 - recall: 0.8062 - val_loss: 0.4780 - val_recall: 0.6927
# Epoch 58/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4317 - recall: 0.7966 - val_loss: 0.4808 - val_recall: 0.6816
# Epoch 59/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4311 - recall: 0.8019 - val_loss: 0.4665 - val_recall: 0.6816
# Epoch 60/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4306 - recall: 0.8068 - val_loss: 0.4907 - val_recall: 0.7318
# Epoch 61/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4385 - recall: 0.7982 - val_loss: 0.4640 - val_recall: 0.6927
# Epoch 62/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4284 - recall: 0.8057 - val_loss: 0.5020 - val_recall: 0.7263
# Epoch 63/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4247 - recall: 0.8143 - val_loss: 0.4702 - val_recall: 0.6872
# Epoch 64/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4351 - recall: 0.7858 - val_loss: 0.5015 - val_recall: 0.7318
# Epoch 65/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4246 - recall: 0.8116 - val_loss: 0.4977 - val_recall: 0.7207
# Epoch 66/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4239 - recall: 0.8095 - val_loss: 0.5016 - val_recall: 0.6983
# Epoch 67/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4226 - recall: 0.8105 - val_loss: 0.4891 - val_recall: 0.7374
# Epoch 68/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4206 - recall: 0.8036 - val_loss: 0.4855 - val_recall: 0.7207
# Epoch 69/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4218 - recall: 0.8170 - val_loss: 0.4635 - val_recall: 0.6983
# Epoch 70/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4234 - recall: 0.7955 - val_loss: 0.4803 - val_recall: 0.7095
# Epoch 71/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4225 - recall: 0.8127 - val_loss: 0.5026 - val_recall: 0.7095
# Epoch 72/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4223 - recall: 0.7982 - val_loss: 0.5269 - val_recall: 0.7765
# Epoch 73/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4196 - recall: 0.8095 - val_loss: 0.4692 - val_recall: 0.6816
# Epoch 74/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4184 - recall: 0.8159 - val_loss: 0.4599 - val_recall: 0.6816
# Epoch 75/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4188 - recall: 0.8100 - val_loss: 0.4948 - val_recall: 0.6983
# Epoch 76/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4145 - recall: 0.8213 - val_loss: 0.4678 - val_recall: 0.6983
# Epoch 77/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4191 - recall: 0.8213 - val_loss: 0.4649 - val_recall: 0.6816
# Epoch 78/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4171 - recall: 0.8105 - val_loss: 0.5088 - val_recall: 0.7207
# Epoch 79/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4192 - recall: 0.8197 - val_loss: 0.5052 - val_recall: 0.7374
# Epoch 80/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4080 - recall: 0.8192 - val_loss: 0.4886 - val_recall: 0.6927
# Epoch 81/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4177 - recall: 0.8235 - val_loss: 0.5027 - val_recall: 0.7318
# Epoch 82/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4112 - recall: 0.8181 - val_loss: 0.4820 - val_recall: 0.7151
# Epoch 83/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4068 - recall: 0.8305 - val_loss: 0.4779 - val_recall: 0.7039
# Epoch 84/500
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4135 - recall: 0.8165 - val_loss: 0.5136 - val_recall: 0.7151
# Epoch 85/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4133 - recall: 0.8235 - val_loss: 0.4910 - val_recall: 0.7207
# Epoch 86/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4120 - recall: 0.8219 - val_loss: 0.5010 - val_recall: 0.6648
# Epoch 87/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4201 - recall: 0.8315 - val_loss: 0.4695 - val_recall: 0.6983
# Epoch 88/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4074 - recall: 0.8208 - val_loss: 0.4499 - val_recall: 0.6760
# Epoch 89/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4051 - recall: 0.8283 - val_loss: 0.4998 - val_recall: 0.6927
# Epoch 90/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4068 - recall: 0.8283 - val_loss: 0.5027 - val_recall: 0.7039
# Epoch 91/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4071 - recall: 0.8267 - val_loss: 0.4903 - val_recall: 0.7039
# Epoch 92/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4072 - recall: 0.8251 - val_loss: 0.4812 - val_recall: 0.6760
# Epoch 93/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4071 - recall: 0.8262 - val_loss: 0.4829 - val_recall: 0.6983
# Epoch 94/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4006 - recall: 0.8337 - val_loss: 0.5029 - val_recall: 0.7207
# Epoch 95/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.3965 - recall: 0.8278 - val_loss: 0.5074 - val_recall: 0.7151
# Epoch 96/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4041 - recall: 0.8262 - val_loss: 0.5582 - val_recall: 0.7654
# Epoch 97/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4107 - recall: 0.8224 - val_loss: 0.4921 - val_recall: 0.7207
# Epoch 98/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4080 - recall: 0.8294 - val_loss: 0.4796 - val_recall: 0.7095
# Epoch 99/500
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4025 - recall: 0.8294 - val_loss: 0.4642 - val_recall: 0.6704
# Epoch 99: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.3517964482307434
# recall :  0.8186274766921997

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 0s 2ms/step
# [[668 128]
#  [ 37 167]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.84      0.89       796
#            1       0.57      0.82      0.67       204
#
#     accuracy                           0.83      1000
#    macro avg       0.76      0.83      0.78      1000
# weighted avg       0.87      0.83      0.85      1000

# %%
model.save('model_churn.h5')

# %% [markdown]
# ![What-is-Behavioral-Intent-Prediction.jpg](attachment:What-is-Behavioral-Intent-Prediction.jpg)

# %% [markdown]
# ### Prediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
single_customer = df.drop('Exited', axis=1).iloc[0]
single_customer
# Out:
# CreditScore            619.000
# Age                     42.000
# Tenure                   2.000
# Balance                  0.000
# NumOfProducts            1.000
# HasCrCard                1.000
# IsActiveMember           1.000
# EstimatedSalary     101348.880
# Geography_Germany        0.000
# Geography_Spain          0.000
# Gender_Male              0.000
# Name: 1, dtype: float64

# %%
single_customer = scaler.transform(single_customer.values.reshape(-1, 11))
single_customer
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673489, 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred =(model.predict(single_customer) > 0.5).astype("int32")
y_pred
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[1]])

# %%
df["Exited"].iloc[0]
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![header-14.png](attachment:header-14.png)

# %% [markdown]
# ## Comparison with ML

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression ,LogisticRegressionCV

# %%
log_model=LogisticRegressionCV(class_weight='balanced')
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[558 238]
#  [ 65 139]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79       796
#            1       0.37      0.68      0.48       204
#
#     accuracy                           0.70      1000
#    macro avg       0.63      0.69      0.63      1000
# weighted avg       0.79      0.70      0.72      1000

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(class_weight='balanced')
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[764  32]
#  [118  86]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.73      0.42      0.53       204
#
#     accuracy                           0.85      1000
#    macro avg       0.80      0.69      0.72      1000
# weighted avg       0.84      0.85      0.83      1000

# %% [markdown]
# ![image.png](attachment:image.png)
