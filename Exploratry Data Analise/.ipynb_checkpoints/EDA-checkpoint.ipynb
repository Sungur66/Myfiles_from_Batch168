# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset("diamonds")

# %% [markdown]
# # Missingno Library

# %%
import missingno as msno

# %%
msno.matrix(df);

# %% [markdown]
# # Summarytool

# %%
# summarytools Python paketi özet istatikleri görüntüler
# !pip install summarytools

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_278b1 thead>tr>th {
#   text-align: left;
# }
# #T_278b1_row0_col0, #T_278b1_row1_col0, #T_278b1_row2_col0, #T_278b1_row3_col0, #T_278b1_row4_col0, #T_278b1_row5_col0, #T_278b1_row6_col0, #T_278b1_row7_col0, #T_278b1_row8_col0, #T_278b1_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_278b1_row0_col1, #T_278b1_row1_col1, #T_278b1_row2_col1, #T_278b1_row3_col1, #T_278b1_row4_col1, #T_278b1_row5_col1, #T_278b1_row6_col1, #T_278b1_row7_col1, #T_278b1_row8_col1, #T_278b1_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_278b1_row0_col2, #T_278b1_row1_col2, #T_278b1_row2_col2, #T_278b1_row3_col2, #T_278b1_row4_col2, #T_278b1_row5_col2, #T_278b1_row6_col2, #T_278b1_row7_col2, #T_278b1_row8_col2, #T_278b1_row9_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_278b1_row0_col3, #T_278b1_row1_col3, #T_278b1_row2_col3, #T_278b1_row3_col3, #T_278b1_row4_col3, #T_278b1_row5_col3, #T_278b1_row6_col3, #T_278b1_row7_col3, #T_278b1_row8_col3, #T_278b1_row9_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_278b1_row0_col4, #T_278b1_row1_col4, #T_278b1_row2_col4, #T_278b1_row3_col4, #T_278b1_row4_col4, #T_278b1_row5_col4, #T_278b1_row6_col4, #T_278b1_row7_col4, #T_278b1_row8_col4, #T_278b1_row9_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_278b1_row0_col5, #T_278b1_row1_col5, #T_278b1_row2_col5, #T_278b1_row3_col5, #T_278b1_row4_col5, #T_278b1_row5_col5, #T_278b1_row6_col5, #T_278b1_row7_col5, #T_278b1_row8_col5, #T_278b1_row9_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_278b1">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 53,940 x 10<br>Duplicates: 146</caption>
#   <thead>
#     <tr>
#       <th id="T_278b1_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_278b1_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_278b1_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_278b1_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_278b1_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_278b1_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_278b1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_278b1_row0_col1" class="data row0 col1" ><strong>carat</strong><br>[float64]</td>
#       <td id="T_278b1_row0_col2" class="data row0 col2" >Mean (sd) : 0.8 (0.5)<br>min < med < max:<br>0.2 < 0.7 < 5.0<br>IQR (CV) : 0.6 (1.7)</td>
#       <td id="T_278b1_row0_col3" class="data row0 col3" >273 distinct values</td>
#       <td id="T_278b1_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_278b1_row1_col1" class="data row1 col1" ><strong>cut</strong><br>[category]</td>
#       <td id="T_278b1_row1_col2" class="data row1 col2" >1. Ideal<br>2. Premium<br>3. Very Good<br>4. Good<br>5. Fair</td>
#       <td id="T_278b1_row1_col3" class="data row1 col3" >21,551 (40.0%)<br>13,791 (25.6%)<br>12,082 (22.4%)<br>4,906 (9.1%)<br>1,610 (3.0%)</td>
#       <td id="T_278b1_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_278b1_row2_col1" class="data row2 col1" ><strong>color</strong><br>[category]</td>
#       <td id="T_278b1_row2_col2" class="data row2 col2" >1. G<br>2. E<br>3. F<br>4. H<br>5. D<br>6. I<br>7. J</td>
#       <td id="T_278b1_row2_col3" class="data row2 col3" >11,292 (20.9%)<br>9,797 (18.2%)<br>9,542 (17.7%)<br>8,304 (15.4%)<br>6,775 (12.6%)<br>5,422 (10.1%)<br>2,808 (5.2%)</td>
#       <td id="T_278b1_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_278b1_row3_col1" class="data row3 col1" ><strong>clarity</strong><br>[category]</td>
#       <td id="T_278b1_row3_col2" class="data row3 col2" >1. SI1<br>2. VS2<br>3. SI2<br>4. VS1<br>5. VVS2<br>6. VVS1<br>7. IF<br>8. I1</td>
#       <td id="T_278b1_row3_col3" class="data row3 col3" >13,065 (24.2%)<br>12,258 (22.7%)<br>9,194 (17.0%)<br>8,171 (15.1%)<br>5,066 (9.4%)<br>3,655 (6.8%)<br>1,790 (3.3%)<br>741 (1.4%)</td>
#       <td id="T_278b1_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_278b1_row4_col1" class="data row4 col1" ><strong>depth</strong><br>[float64]</td>
#       <td id="T_278b1_row4_col2" class="data row4 col2" >Mean (sd) : 61.7 (1.4)<br>min < med < max:<br>43.0 < 61.8 < 79.0<br>IQR (CV) : 1.5 (43.1)</td>
#       <td id="T_278b1_row4_col3" class="data row4 col3" >184 distinct values</td>
#       <td id="T_278b1_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_278b1_row5_col1" class="data row5 col1" ><strong>table</strong><br>[float64]</td>
#       <td id="T_278b1_row5_col2" class="data row5 col2" >Mean (sd) : 57.5 (2.2)<br>min < med < max:<br>43.0 < 57.0 < 95.0<br>IQR (CV) : 3.0 (25.7)</td>
#       <td id="T_278b1_row5_col3" class="data row5 col3" >127 distinct values</td>
#       <td id="T_278b1_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_278b1_row6_col1" class="data row6 col1" ><strong>price</strong><br>[int64]</td>
#       <td id="T_278b1_row6_col2" class="data row6 col2" >Mean (sd) : 3932.8 (3989.4)<br>min < med < max:<br>326.0 < 2401.0 < 18823.0<br>IQR (CV) : 4374.2 (1.0)</td>
#       <td id="T_278b1_row6_col3" class="data row6 col3" >11,602 distinct values</td>
#       <td id="T_278b1_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_278b1_row7_col1" class="data row7 col1" ><strong>x</strong><br>[float64]</td>
#       <td id="T_278b1_row7_col2" class="data row7 col2" >Mean (sd) : 5.7 (1.1)<br>min < med < max:<br>0.0 < 5.7 < 10.7<br>IQR (CV) : 1.8 (5.1)</td>
#       <td id="T_278b1_row7_col3" class="data row7 col3" >554 distinct values</td>
#       <td id="T_278b1_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_278b1_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_278b1_row8_col1" class="data row8 col1" ><strong>y</strong><br>[float64]</td>
#       <td id="T_278b1_row8_col2" class="data row8 col2" >Mean (sd) : 5.7 (1.1)<br>min < med < max:<br>0.0 < 5.7 < 58.9<br>IQR (CV) : 1.8 (5.0)</td>
#       <td id="T_278b1_row8_col3" class="data row8 col3" >552 distinct values</td>
#       <td id="T_278b1_row8_col4" class="data row8 col4" ><img src = "......"></img></td>
#       <td id="T_278b1_row8_col5" class="data row8 col5" >0<br>(0.0%)</td>
#     </tr>

# %% [markdown]
# # Skewnes

# %%
from scipy.stats import skew

# %%
for i in df.drop(columns = "sales").columns:
    print(i, skew(df[i]))

# %%
for j in df.drop(columns = "sales").columns:     #"sales" sütunu dataframe'den kaldırılıyor
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))   #  j sütununa ait veri dağılımı grafiği çiziliyor. grafiğin üzerinde gösterilen etiketi oluşturur. Etiket, o sütunun çarpıklık değerini (skewness) içerir
    g = g.legend(loc= "best")   #  grafiğin üzerine eklenen etiketin konumunu en iyi yere yerleştirmes
    plt.show()
